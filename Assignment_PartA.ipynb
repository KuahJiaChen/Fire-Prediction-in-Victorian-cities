# %% [markdown]
# # Assignment Part A

# %% [markdown]
# Student Name: Kuah Jia Chen <br>
# Student ID: 32286988

# %% [markdown]
# ## Task 1. Mongo Data Model
#
# 1. Based on the two data sets provided i.e. hotspot_historic.csv and climate_historic.csv, design a suitable data model to support the efficient querying of the two data sets in MongoDB. Justify your data model design. The output of this task should be
# - An example of the data model.
# - The justification for choosing that data model.

# %% [markdown]
# ### Answer
#
# I will be choosing to construct an embedded data model for this assignment.
#
# (1) An example of the data model.
#
# `The code I used to generate the example of the data model:`
# ```
# from datetime import datetime
#
# target_date = '27-12-2021'
# target_date_obj = datetime.strptime(target_date, '%d-%m-%Y')
#
# cursor = db.embedded_climate_hotspot.find(
#     {'date':target_date_obj}
# )
# for document in cursor:
#     document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
#     pprint(document)
# ```
#
# `The example of the data model:`
# ```
# {'GHI_w/m2': 223,
#  '_id': ObjectId('6283030ad9df33cead533f80'),
#  'air_temperature_celcius': 28,
#  'date': '27-12-2021',
#  'hotspots': [{'_id': ObjectId('6283030dd9df33cead533f86'),
#                'confidence': 78,
#                'date': datetime.datetime(2021, 12, 27, 0, 0),
#                'datetime': datetime.datetime(2021, 12, 27, 4, 16, 51),
#                'latitude': -37.966,
#                'longitude': 145.05100000000002,
#                'surface_temperature_celcius': 68},
#               {'_id': ObjectId('6283030dd9df33cead533f87'),
#                'confidence': 82,
#                'date': datetime.datetime(2021, 12, 27, 0, 0),
#                'datetime': datetime.datetime(2021, 12, 27, 0, 2, 15),
#                'latitude': -35.541,
#                'longitude': 143.311,
#                'surface_temperature_celcius': 63},
#               {'_id': ObjectId('6283030dd9df33cead533f88'),
#                'confidence': 67,
#                'date': datetime.datetime(2021, 12, 27, 0, 0),
#                'datetime': datetime.datetime(2021, 12, 27, 0, 2, 15),
#                'latitude': -35.554,
#                'longitude': 143.30700000000002,
#                'surface_temperature_celcius': 53},
#               {'_id': ObjectId('6283030dd9df33cead533f89'),
#                'confidence': 86,
#                'date': datetime.datetime(2021, 12, 27, 0, 0),
#                'datetime': datetime.datetime(2021, 12, 27, 0, 2, 14),
#                'latitude': -35.543,
#                'longitude': 143.316,
#                'surface_temperature_celcius': 67}],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# ```
# `Explanation of how the data is stored:`
#
# The example above shows one of the documents in my result collection using the embedded data model. To construct the embedded data model, for each climate data, I will create an array called "hotspots" and for each hotspot data with the same date as this climate data, I will append them to this array. The example above is the climate data for 27/12/2021. We can see that in the "hotspots" array, it stores all the hotspot data that happens on 27/12/2021.
#
#
# (2) The justification for choosing that data model.
# - According to the questions in task 2, I am required to obtain data from both CSV files. Hence, if I use referencing data model, I have to use aggregation to perform the left outer join several times for the queries in task 2, and thus the total join cost will be expensive and time-consuming when the data becomes big. Besides that, using the referencing data model and doing the join at the programming level can be very complex. However, for the embedded data model, I do not have to perform any join operation as everything is in one collection, therefore this method is fast and easy.
#
# - If I choose the referencing data model, it means that I have two options based on the slides in lecture 7. Assuming I have created two collections named "climate" and "hotspot" based on the data in "climate_historic" and hotspot_historic" respectively. The first method is that for each document of "climate", I will use an array to store all the id of the fire data (i.e., from hotspot) that happens on that date. The second method is that for each document in "hotspot" collection, I will need to create a new field called "climate_id" and it will store the object id of a particular climate document that has the same date as this document. However, for the first method, it would be a problem if the total document of "hotspot" on a particular date is large. The reason is that the array of this document in "climate" will be very long, hence it makes the querying of data inefficient. Besides that, for the second method, if we want to find the data for a particular date, we need to go through every document in a "hotspot", and this has to be done in every query of data. Thus, it is inefficient. Nevertheless, for the embedded data model, since our data is not large, if we want to find the data for a particular date, we could just go to that document and query it, which is more efficient than the previous method. Consequently, I decided to use an embedded data model.
#
# - Using an embedded data model means everything I need is in a single collection, as a result, it means fewer queries and updates (if necessary) are needed. Thus, it is more convenient. Moreover, since MongoDB does not allow normalization, hence it is fine to have duplicate data or data with a different format in the result collection, so the embedded model is allowed in this situation.

# %% [markdown]
# ## Task 2. Querying MongoDB using PyMongo

# %% [markdown]
# ### 1) Write a python program that will read the data from hotspot_historic.csv and climate_historic.csv and load them to the new database (e.g.fit3182_assignment_db). The collection(s) in fit3182_assignment_db will be based on the document model you have designed in Task A1.
# - Please use a csv library to read the files.
# - Please DO NOT use the mongo aggregation query to do this task.

# %%
from pymongo import MongoClient
from pprint import pprint

# Create a MongoClient/Mongodb connection 
client = MongoClient()

# We will use the database: fit3182_assignment_db
db = client.fit3182_assignment_db

# The collection name is climate and hotspot
climate = db.climate
hotspot = db.hotspot

# %%
# delete this collection if it is exists in the database
db.embedded_climate_hotspot.drop()
db.climate.drop()
db.hotspot.drop()

# %%
import pandas as pd

# Use csv to read the data
climate_data = pd.read_csv("climate_historic.csv")
climate_data.dtypes
climate_data['date'] = pd.to_datetime(climate_data['date'], format="%d/%m/%y")
climate_data['date'] = climate_data['date'].dt.strftime('%d-%m-%Y')
climate.insert_many(climate_data.to_dict('records'))

# %%
# change the data type of date column to date
db.climate.update_many(
   {
      "date":{
         "$type":"string"
      }
   },
   [
      {
         "$set":{
            "date":{
               "$dateFromString":{
                  "dateString":"$date",
                  "format":"%d-%m-%Y"
               }
            }
         }
      }
   ]
)

# %%
# Use csv to read the data
hotspot_data = pd.read_csv("hotspot_historic.csv")
hotspot_data['date'] = pd.to_datetime(hotspot_data['date'], format="%d/%m/%Y")
hotspot_data['date'] = hotspot_data['date'].dt.strftime('%d-%m-%Y')
hotspot.insert_many(hotspot_data.to_dict('records'))

# %%
# change the data type of date column to date
db.hotspot.update_many(
   {
      "date":{
         "$type":"string"
      }
   },
   [
      {
         "$set":{
            "date":{
               "$dateFromString":{
                  "dateString":"$date",
                  "format":"%d-%m-%Y"
               }
            }
         }
      }
   ]
)

# %%
# change the data type of datetime column to datetime
db.hotspot.update_many(
   {
      "datetime":{
         "$type":"string"
      }
   },
   [
      {
         "$set":{
            "datetime":{
               "$dateFromString":{
                  "dateString":"$datetime"
               }
            }
         }
      }
   ]
)

# %%
# construct the embedded model
# Prepare the data following the data model with proper data format
all_date = db.climate.distinct("date")                                     # find all the unique date 
for date in all_date:                                                      # for each unique data
    matched_documents = hotspot.find({"date":date})                        # find the hotspot data with the same data 
    current = []                                                           
    for document in matched_documents:
        current.append(document)                                           # append those hotspot data into a single list
    climate.update_one({"date":date},{"$set":{"hotspots":current}})        # add the result list to the climate data

# %%
# rename the collection
db.climate.rename("embedded_climate_hotspot")
# Out:
# {'ok': 1.0}

# %%
hotspot.drop()

# %% [markdown]
# Now, all the data has been successfully loaded into Mongodb. (i.e., the collection in fit3182_assignment_db database)

# %% [markdown]
# ### 2) Write queries to answer the following tasks on fit3182_assignment_db and corresponding collection(s). You need to write the queries as a python program using the pymongo library in Jupyter Notebook.

# %% [markdown]
# #### a) Find climate data on 12th December 2021.

# %%
from datetime import datetime

target_date = '12-12-2021'
target_date_obj = datetime.strptime(target_date, '%d-%m-%Y')  # convert the string to date object

cursor = db.embedded_climate_hotspot.find(
    {'date':target_date_obj},
    {"_id":0,"hotspots":0} # hotspots are not needed
)
for document in cursor: 
    document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
    pprint(document)
# Out:
# {'GHI_w/m2': 156,
#  'air_temperature_celcius': 19,
#  'date': '12-12-2021',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %% [markdown]
# #### b) Find the latitude, longitude, surface temperature (°C), and confidence when the surface temperature (°C) was between 65 °C and 100 °C.

# %%
cursor = db.embedded_climate_hotspot.aggregate([
    # since necessary details are in an associative array, hence I need to use unwind
    {"$unwind":"$hotspots"},          
    # make sure the surface temperature was between 65 and 100 inclusive
    {"$match": {"$and":[{"hotspots.surface_temperature_celcius":{"$gt":64}},\
                        {"hotspots.surface_temperature_celcius":{"$lt":101}}]}},
    # only output the necessary details
    {"$project":{"hotspots.latitude":1,"hotspots.longitude":1,"hotspots.surface_temperature_celcius":1,\
                 "hotspots.confidence":1,"_id":0}}
])


for document in cursor: 
    pprint(document['hotspots']) # only print the value in 'hotspots' as that is the necessary part
# Out:
# {'confidence': 94,
#  'latitude': -37.2284,
#  'longitude': 147.9187,
#  'surface_temperature_celcius': 73}
# {'confidence': 97,
#  'latitude': -37.6572,
#  'longitude': 142.0703,
#  'surface_temperature_celcius': 80}
# {'confidence': 84,
#  'latitude': -37.0193,
#  'longitude': 148.1459,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.4229,
#  'longitude': 147.02700000000002,
#  'surface_temperature_celcius': 99}
# {'confidence': 80,
#  'latitude': -37.0055,
#  'longitude': 148.1582,
#  'surface_temperature_celcius': 68}
# {'confidence': 85,
#  'latitude': -37.4128,
#  'longitude': 147.0242,
#  'surface_temperature_celcius': 98}
# {'confidence': 90,
#  'latitude': -34.357,
#  'longitude': 141.5361,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -34.3539,
#  'longitude': 141.5547,
#  'surface_temperature_celcius': 72}
# {'confidence': 90,
#  'latitude': -36.9939,
#  'longitude': 148.2244,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.9959,
#  'longitude': 148.2118,
#  'surface_temperature_celcius': 75}
# {'confidence': 89,
#  'latitude': -34.3654,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -34.3554,
#  'longitude': 141.5413,
#  'surface_temperature_celcius': 79}
# {'confidence': 94,
#  'latitude': -34.3555,
#  'longitude': 141.5495,
#  'surface_temperature_celcius': 75}
# {'confidence': 94,
#  'latitude': -36.7152,
#  'longitude': 141.3853,
#  'surface_temperature_celcius': 74}
# {'confidence': 97,
#  'latitude': -37.0155,
#  'longitude': 148.1432,
#  'surface_temperature_celcius': 80}
# {'confidence': 96,
#  'latitude': -37.6622,
#  'longitude': 142.1001,
#  'surface_temperature_celcius': 79}
# {'confidence': 90,
#  'latitude': -37.4523,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 66}
# {'confidence': 98,
#  'latitude': -37.4261,
#  'longitude': 147.0323,
#  'surface_temperature_celcius': 83}
# {'confidence': 100,
#  'latitude': -37.3949,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 91}
# {'confidence': 92,
#  'latitude': -37.6625,
#  'longitude': 144.287,
#  'surface_temperature_celcius': 70}
# {'confidence': 82,
#  'latitude': -37.8973,
#  'longitude': 143.4754,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -37.7805,
#  'longitude': 143.5003,
#  'surface_temperature_celcius': 75}
# {'confidence': 95,
#  'latitude': -37.8774,
#  'longitude': 145.8213,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -37.8881,
#  'longitude': 145.8229,
#  'surface_temperature_celcius': 99}
# {'confidence': 71,
#  'latitude': -37.522,
#  'longitude': 143.3874,
#  'surface_temperature_celcius': 73}
# {'confidence': 91,
#  'latitude': -38.0674,
#  'longitude': 142.965,
#  'surface_temperature_celcius': 68}
# {'confidence': 92,
#  'latitude': -38.0715,
#  'longitude': 142.9591,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -38.0693,
#  'longitude': 142.9722,
#  'surface_temperature_celcius': 89}
# {'confidence': 92,
#  'latitude': -36.4557,
#  'longitude': 142.2434,
#  'surface_temperature_celcius': 71}
# {'confidence': 95,
#  'latitude': -36.8009,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 76}
# {'confidence': 93,
#  'latitude': -36.8099,
#  'longitude': 142.72799999999998,
#  'surface_temperature_celcius': 73}
# {'confidence': 94,
#  'latitude': -36.7806,
#  'longitude': 141.5597,
#  'surface_temperature_celcius': 74}
# {'confidence': 98,
#  'latitude': -34.3526,
#  'longitude': 141.6458,
#  'surface_temperature_celcius': 82}
# {'confidence': 97,
#  'latitude': -37.0924,
#  'longitude': 141.89700000000002,
#  'surface_temperature_celcius': 80}
# {'confidence': 97,
#  'latitude': -37.9452,
#  'longitude': 143.5834,
#  'surface_temperature_celcius': 80}
# {'confidence': 99,
#  'latitude': -34.351,
#  'longitude': 141.6567,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -37.5012,
#  'longitude': 142.5853,
#  'surface_temperature_celcius': 90}
# {'confidence': 97,
#  'latitude': -37.9247,
#  'longitude': 142.8999,
#  'surface_temperature_celcius': 81}
# {'confidence': 97,
#  'latitude': -35.0805,
#  'longitude': 142.4642,
#  'surface_temperature_celcius': 81}
# {'confidence': 87,
#  'latitude': -37.3735,
#  'longitude': 145.886,
#  'surface_temperature_celcius': 96}
# {'confidence': 93,
#  'latitude': -37.7465,
#  'longitude': 143.3806,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -37.8072,
#  'longitude': 145.9738,
#  'surface_temperature_celcius': 77}
# {'confidence': 96,
#  'latitude': -37.3704,
#  'longitude': 145.8942,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -37.297,
#  'longitude': 143.5753,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -37.2988,
#  'longitude': 143.5487,
#  'surface_temperature_celcius': 90}
# {'confidence': 100,
#  'latitude': -37.3025,
#  'longitude': 143.5714,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.383,
#  'longitude': 145.9089,
#  'surface_temperature_celcius': 89}
# {'confidence': 89,
#  'latitude': -37.7446,
#  'longitude': 143.4085,
#  'surface_temperature_celcius': 66}
# {'confidence': 98,
#  'latitude': -37.7509,
#  'longitude': 143.4023,
#  'surface_temperature_celcius': 82}
# {'confidence': 87,
#  'latitude': -37.7974,
#  'longitude': 145.9535,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -35.7657,
#  'longitude': 142.0906,
#  'surface_temperature_celcius': 66}
# {'confidence': 99,
#  'latitude': -37.7236,
#  'longitude': 143.3995,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -37.3046,
#  'longitude': 143.5448,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -36.4312,
#  'longitude': 141.2064,
#  'surface_temperature_celcius': 76}
# {'confidence': 89,
#  'latitude': -36.1556,
#  'longitude': 141.5904,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -35.7647,
#  'longitude': 142.0858,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -35.4033,
#  'longitude': 143.267,
#  'surface_temperature_celcius': 67}
# {'confidence': 64,
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
# {'confidence': 85,
#  'latitude': -36.111,
#  'longitude': 145.124,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.1615,
#  'longitude': 141.8728,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.1122,
#  'longitude': 142.1491,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.3735,
#  'longitude': 145.8384,
#  'surface_temperature_celcius': 95}
# {'confidence': 89,
#  'latitude': -35.4255,
#  'longitude': 143.6306,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -36.1955,
#  'longitude': 145.914,
#  'surface_temperature_celcius': 78}
# {'confidence': 85,
#  'latitude': -35.4533,
#  'longitude': 143.2029,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.5989,
#  'longitude': 141.9771,
#  'surface_temperature_celcius': 81}
# {'confidence': 66,
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
# {'confidence': 97,
#  'latitude': -36.1925,
#  'longitude': 145.93,
#  'surface_temperature_celcius': 79}
# {'confidence': 98,
#  'latitude': -36.095,
#  'longitude': 141.7699,
#  'surface_temperature_celcius': 82}
# {'confidence': 96,
#  'latitude': -36.6006,
#  'longitude': 141.9657,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -37.0769,
#  'longitude': 141.042,
#  'surface_temperature_celcius': 72}
# {'confidence': 79,
#  'latitude': -36.883,
#  'longitude': 142.1637,
#  'surface_temperature_celcius': 67}
# {'confidence': 87,
#  'latitude': -36.0973,
#  'longitude': 143.4279,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -36.1819,
#  'longitude': 145.9269,
#  'surface_temperature_celcius': 98}
# {'confidence': 87,
#  'latitude': -37.6387,
#  'longitude': 142.9032,
#  'surface_temperature_celcius': 88}
# {'confidence': 93,
#  'latitude': -37.6439,
#  'longitude': 142.91299999999998,
#  'surface_temperature_celcius': 83}
# {'confidence': 93,
#  'latitude': -37.3165,
#  'longitude': 147.4932,
#  'surface_temperature_celcius': 72}
# {'confidence': 95,
#  'latitude': -37.3158,
#  'longitude': 147.4986,
#  'surface_temperature_celcius': 76}
# {'confidence': 89,
#  'latitude': -37.4471,
#  'longitude': 147.6331,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -37.7835,
#  'longitude': 148.4138,
#  'surface_temperature_celcius': 66}
# {'confidence': 89,
#  'latitude': -37.4449,
#  'longitude': 147.6594,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -37.4323,
#  'longitude': 147.6583,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.4343,
#  'longitude': 147.6327,
#  'surface_temperature_celcius': 92}
# {'confidence': 84,
#  'latitude': -37.5816,
#  'longitude': 148.5862,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.6334,
#  'longitude': 142.2244,
#  'surface_temperature_celcius': 69}
# {'confidence': 76,
#  'latitude': -37.7966,
#  'longitude': 142.3196,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -35.805,
#  'longitude': 142.1326,
#  'surface_temperature_celcius': 95}
# {'confidence': 100,
#  'latitude': -37.8429,
#  'longitude': 143.8366,
#  'surface_temperature_celcius': 88}
# {'confidence': 77,
#  'latitude': -37.8062,
#  'longitude': 143.3598,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -36.9918,
#  'longitude': 141.8667,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -36.1104,
#  'longitude': 145.9829,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.782,
#  'longitude': 148.3844,
#  'surface_temperature_celcius': 99}
# {'confidence': 89,
#  'latitude': -36.9902,
#  'longitude': 141.879,
#  'surface_temperature_celcius': 65}
# {'confidence': 89,
#  'latitude': -37.745,
#  'longitude': 142.993,
#  'surface_temperature_celcius': 65}
# {'confidence': 92,
#  'latitude': -36.0157,
#  'longitude': 145.9414,
#  'surface_temperature_celcius': 70}
# {'confidence': 99,
#  'latitude': -37.777,
#  'longitude': 148.4128,
#  'surface_temperature_celcius': 85}
# {'confidence': 93,
#  'latitude': -37.5888,
#  'longitude': 148.5949,
#  'surface_temperature_celcius': 72}
# {'confidence': 89,
#  'latitude': -34.3943,
#  'longitude': 141.7567,
#  'surface_temperature_celcius': 65}
# {'confidence': 81,
#  'latitude': -36.0844,
#  'longitude': 141.4934,
#  'surface_temperature_celcius': 71}
# {'confidence': 91,
#  'latitude': -36.031,
#  'longitude': 145.6824,
#  'surface_temperature_celcius': 69}
# {'confidence': 86,
#  'latitude': -37.5814,
#  'longitude': 148.5777,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -37.5788,
#  'longitude': 148.592,
#  'surface_temperature_celcius': 67}
# {'confidence': 90,
#  'latitude': -36.6384,
#  'longitude': 142.4075,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -35.811,
#  'longitude': 142.1403,
#  'surface_temperature_celcius': 96}
# {'confidence': 100,
#  'latitude': -36.9034,
#  'longitude': 141.0013,
#  'surface_temperature_celcius': 95}
# {'confidence': 88,
#  'latitude': -37.7746,
#  'longitude': 148.3673,
#  'surface_temperature_celcius': 65}
# {'confidence': 83,
#  'latitude': -37.803000000000004,
#  'longitude': 142.3151,
#  'surface_temperature_celcius': 78}
# {'confidence': 96,
#  'latitude': -37.7542,
#  'longitude': 142.9949,
#  'surface_temperature_celcius': 77}
# {'confidence': 91,
#  'latitude': -37.3803,
#  'longitude': 145.611,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -37.7617,
#  'longitude': 143.08100000000002,
#  'surface_temperature_celcius': 81}
# {'confidence': 92,
#  'latitude': -37.8161,
#  'longitude': 142.9286,
#  'surface_temperature_celcius': 71}
# {'confidence': 90,
#  'latitude': -36.0387,
#  'longitude': 145.6787,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -36.6349,
#  'longitude': 142.2125,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -36.9018,
#  'longitude': 141.0146,
#  'surface_temperature_celcius': 100}
# {'confidence': 86,
#  'latitude': -36.6986,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -38.0052,
#  'longitude': 142.6179,
#  'surface_temperature_celcius': 89}
# {'confidence': 100,
#  'latitude': -37.2168,
#  'longitude': 147.4748,
#  'surface_temperature_celcius': 89}
# {'confidence': 96,
#  'latitude': -37.222,
#  'longitude': 147.4689,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -37.2063,
#  'longitude': 147.4713,
#  'surface_temperature_celcius': 70}
# {'confidence': 92,
#  'latitude': -37.2082,
#  'longitude': 147.4368,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -37.224000000000004,
#  'longitude': 147.4347,
#  'surface_temperature_celcius': 76}
# {'confidence': 67,
#  'latitude': -37.34,
#  'longitude': 149.3668,
#  'surface_temperature_celcius': 74}
# {'confidence': 99,
#  'latitude': -36.7287,
#  'longitude': 142.6017,
#  'surface_temperature_celcius': 85}
# {'confidence': 91,
#  'latitude': -35.2363,
#  'longitude': 143.0004,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -35.2378,
#  'longitude': 142.9864,
#  'surface_temperature_celcius': 94}
# {'confidence': 98,
#  'latitude': -35.2381,
#  'longitude': 142.994,
#  'surface_temperature_celcius': 83}
# {'confidence': 66,
#  'latitude': -37.3493,
#  'longitude': 149.3691,
#  'surface_temperature_celcius': 80}
# {'confidence': 90,
#  'latitude': -36.7165,
#  'longitude': 142.6155,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -37.5812,
#  'longitude': 142.7374,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -37.5949,
#  'longitude': 142.6857,
#  'surface_temperature_celcius': 98}
# {'confidence': 95,
#  'latitude': -37.8247,
#  'longitude': 143.6243,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.4028,
#  'longitude': 143.6932,
#  'surface_temperature_celcius': 75}
# {'confidence': 92,
#  'latitude': -37.4033,
#  'longitude': 143.6884,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.8249,
#  'longitude': 143.6174,
#  'surface_temperature_celcius': 98}
# {'confidence': 93,
#  'latitude': -36.6823,
#  'longitude': 142.5024,
#  'surface_temperature_celcius': 71}
# {'confidence': 93,
#  'latitude': -36.4489,
#  'longitude': 144.7685,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -36.9498,
#  'longitude': 142.2012,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -36.1941,
#  'longitude': 143.1604,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -36.4142,
#  'longitude': 143.1077,
#  'surface_temperature_celcius': 97}
# {'confidence': 92,
#  'latitude': -36.1924,
#  'longitude': 143.1716,
#  'surface_temperature_celcius': 70}
# {'confidence': 89,
#  'latitude': -36.0295,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.0761,
#  'longitude': 141.0574,
#  'surface_temperature_celcius': 89}
# {'confidence': 93,
#  'latitude': -35.0616,
#  'longitude': 141.4417,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -36.3999,
#  'longitude': 144.737,
#  'surface_temperature_celcius': 88}
# {'confidence': 91,
#  'latitude': -36.1748,
#  'longitude': 145.7582,
#  'surface_temperature_celcius': 69}
# {'confidence': 99,
#  'latitude': -36.0691,
#  'longitude': 145.7797,
#  'surface_temperature_celcius': 85}
# {'confidence': 90,
#  'latitude': -35.1949,
#  'longitude': 141.0622,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -36.91,
#  'longitude': 141.2705,
#  'surface_temperature_celcius': 96}
# {'confidence': 89,
#  'latitude': -35.8071,
#  'longitude': 142.7318,
#  'surface_temperature_celcius': 66}
# {'confidence': 97,
#  'latitude': -36.7787,
#  'longitude': 141.4449,
#  'surface_temperature_celcius': 80}
# {'confidence': 98,
#  'latitude': -36.2948,
#  'longitude': 141.3486,
#  'surface_temperature_celcius': 82}
# {'confidence': 89,
#  'latitude': -38.1561,
#  'longitude': 143.7846,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -37.8185,
#  'longitude': 142.5609,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -36.1771,
#  'longitude': 145.7451,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -38.027,
#  'longitude': 142.3844,
#  'surface_temperature_celcius': 95}
# {'confidence': 89,
#  'latitude': -35.7642,
#  'longitude': 143.3321,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -36.429,
#  'longitude': 141.5759,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.1346,
#  'longitude': 145.2196,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.0899,
#  'longitude': 141.0238,
#  'surface_temperature_celcius': 90}
# {'confidence': 95,
#  'latitude': -36.3823,
#  'longitude': 141.3146,
#  'surface_temperature_celcius': 77}
# {'confidence': 90,
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.5243,
#  'longitude': 142.0839,
#  'surface_temperature_celcius': 72}
# {'confidence': 98,
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'surface_temperature_celcius': 82}
# {'confidence': 90,
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.9364,
#  'longitude': 143.4996,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.3847,
#  'longitude': 142.8935,
#  'surface_temperature_celcius': 88}
# {'confidence': 100,
#  'latitude': -35.6374,
#  'longitude': 142.3787,
#  'surface_temperature_celcius': 95}
# {'confidence': 90,
#  'latitude': -36.8835,
#  'longitude': 142.2098,
#  'surface_temperature_celcius': 67}
# {'confidence': 100,
#  'latitude': -36.4125,
#  'longitude': 143.1189,
#  'surface_temperature_celcius': 92}
# {'confidence': 97,
#  'latitude': -37.0669,
#  'longitude': 141.0556,
#  'surface_temperature_celcius': 80}
# {'confidence': 92,
#  'latitude': -36.0714,
#  'longitude': 145.7665,
#  'surface_temperature_celcius': 71}
# {'confidence': 94,
#  'latitude': -36.2933,
#  'longitude': 141.36,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -37.4591,
#  'longitude': 144.9492,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -36.3487,
#  'longitude': 145.5315,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -36.5399,
#  'longitude': 144.678,
#  'surface_temperature_celcius': 66}
# {'confidence': 97,
#  'latitude': -36.8158,
#  'longitude': 142.6229,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.4518,
#  'longitude': 144.7752,
#  'surface_temperature_celcius': 97}
# {'confidence': 90,
#  'latitude': -36.7903,
#  'longitude': 141.618,
#  'surface_temperature_celcius': 67}
# {'confidence': 97,
#  'latitude': -36.1067,
#  'longitude': 143.7948,
#  'surface_temperature_celcius': 79}
# {'confidence': 89,
#  'latitude': -36.1441,
#  'longitude': 145.2221,
#  'surface_temperature_celcius': 65}
# {'confidence': 94,
#  'latitude': -36.4816,
#  'longitude': 141.6635,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -36.0837,
#  'longitude': 144.2448,
#  'surface_temperature_celcius': 87}
# {'confidence': 90,
#  'latitude': -36.782,
#  'longitude': 141.8851,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.5586,
#  'longitude': 144.0423,
#  'surface_temperature_celcius': 71}
# {'confidence': 90,
#  'latitude': -36.5568,
#  'longitude': 144.0538,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -36.4538,
#  'longitude': 144.763,
#  'surface_temperature_celcius': 81}
# {'confidence': 91,
#  'latitude': -36.4612,
#  'longitude': 144.7775,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.7089,
#  'longitude': 143.3518,
#  'surface_temperature_celcius': 93}
# {'confidence': 97,
#  'latitude': -36.601,
#  'longitude': 144.6378,
#  'surface_temperature_celcius': 80}
# {'confidence': 95,
#  'latitude': -36.8681,
#  'longitude': 143.5186,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -37.1999,
#  'longitude': 143.8231,
#  'surface_temperature_celcius': 90}
# {'confidence': 91,
#  'latitude': -37.6171,
#  'longitude': 142.9426,
#  'surface_temperature_celcius': 68}
# {'confidence': 84,
#  'latitude': -37.7587,
#  'longitude': 142.8521,
#  'surface_temperature_celcius': 80}
# {'confidence': 91,
#  'latitude': -37.4611,
#  'longitude': 144.9371,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -38.0254,
#  'longitude': 142.3959,
#  'surface_temperature_celcius': 99}
# {'confidence': 89,
#  'latitude': -37.88,
#  'longitude': 143.7233,
#  'surface_temperature_celcius': 65}
# {'confidence': 99,
#  'latitude': -37.8885,
#  'longitude': 143.9157,
#  'surface_temperature_celcius': 85}
# {'confidence': 95,
#  'latitude': -35.0706,
#  'longitude': 141.4435,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -38.0795,
#  'longitude': 143.2449,
#  'surface_temperature_celcius': 91}
# {'confidence': 100,
#  'latitude': -35.1857,
#  'longitude': 141.0604,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -35.6469,
#  'longitude': 142.376,
#  'surface_temperature_celcius': 93}
# {'confidence': 91,
#  'latitude': -35.6453,
#  'longitude': 142.387,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -36.4409,
#  'longitude': 141.6948,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -37.9174,
#  'longitude': 145.8678,
#  'surface_temperature_celcius': 93}
# {'confidence': 95,
#  'latitude': -37.9152,
#  'longitude': 145.8808,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.8906,
#  'longitude': 146.2035,
#  'surface_temperature_celcius': 75}
# {'confidence': 100,
#  'latitude': -35.8182,
#  'longitude': 143.8739,
#  'surface_temperature_celcius': 92}
# {'confidence': 100,
#  'latitude': -37.9246,
#  'longitude': 146.2464,
#  'surface_temperature_celcius': 96}
# {'confidence': 94,
#  'latitude': -36.3313,
#  'longitude': 141.0017,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.2857,
#  'longitude': 141.3467,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.0749,
#  'longitude': 143.4058,
#  'surface_temperature_celcius': 70}
# {'confidence': 91,
#  'latitude': -36.4449,
#  'longitude': 140.9836,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.3972,
#  'longitude': 141.6041,
#  'surface_temperature_celcius': 90}
# {'confidence': 90,
#  'latitude': -36.5532,
#  'longitude': 142.5349,
#  'surface_temperature_celcius': 67}
# {'confidence': 92,
#  'latitude': -36.1367,
#  'longitude': 145.2071,
#  'surface_temperature_celcius': 71}
# {'confidence': 96,
#  'latitude': -36.1518,
#  'longitude': 144.0233,
#  'surface_temperature_celcius': 79}
# {'confidence': 95,
#  'latitude': -36.1418,
#  'longitude': 144.0261,
#  'surface_temperature_celcius': 76}
# {'confidence': 75,
#  'latitude': -36.7499,
#  'longitude': 141.3006,
#  'surface_temperature_celcius': 99}
# {'confidence': 84,
#  'latitude': -36.7432,
#  'longitude': 141.3296,
#  'surface_temperature_celcius': 79}
# {'confidence': 84,
#  'latitude': -36.7531,
#  'longitude': 141.3253,
#  'surface_temperature_celcius': 78}
# {'confidence': 99,
#  'latitude': -36.7943,
#  'longitude': 143.9571,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -36.7957,
#  'longitude': 143.9652,
#  'surface_temperature_celcius': 87}
# {'confidence': 98,
#  'latitude': -36.9329,
#  'longitude': 143.7796,
#  'surface_temperature_celcius': 82}
# {'confidence': 99,
#  'latitude': -35.8276,
#  'longitude': 143.7549,
#  'surface_temperature_celcius': 85}
# {'confidence': 78,
#  'latitude': -35.9326,
#  'longitude': 141.958,
#  'surface_temperature_celcius': 66}
# {'confidence': 91,
#  'latitude': -36.6892,
#  'longitude': 145.2775,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -36.73,
#  'longitude': 143.935,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -36.8283,
#  'longitude': 143.4605,
#  'surface_temperature_celcius': 93}
# {'confidence': 97,
#  'latitude': -36.6527,
#  'longitude': 142.7392,
#  'surface_temperature_celcius': 81}
# {'confidence': 96,
#  'latitude': -36.1898,
#  'longitude': 145.0922,
#  'surface_temperature_celcius': 78}
# {'confidence': 96,
#  'latitude': -36.8298,
#  'longitude': 143.4483,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -36.6615,
#  'longitude': 144.6014,
#  'surface_temperature_celcius': 90}
# {'confidence': 93,
#  'latitude': -36.8238,
#  'longitude': 143.5724,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -36.1988,
#  'longitude': 145.0941,
#  'surface_temperature_celcius': 100}
# {'confidence': 91,
#  'latitude': -36.7651,
#  'longitude': 143.5801,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.5199,
#  'longitude': 144.7311,
#  'surface_temperature_celcius': 77}
# {'confidence': 91,
#  'latitude': -37.0782,
#  'longitude': 145.3625,
#  'surface_temperature_celcius': 68}
# {'confidence': 94,
#  'latitude': -36.3966,
#  'longitude': 141.406,
#  'surface_temperature_celcius': 74}
# {'confidence': 90,
#  'latitude': -37.1349,
#  'longitude': 141.9491,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -37.6397,
#  'longitude': 142.5968,
#  'surface_temperature_celcius': 68}
# {'confidence': 90,
#  'latitude': -37.6267,
#  'longitude': 142.9993,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.5871,
#  'longitude': 144.4958,
#  'surface_temperature_celcius': 72}
# {'confidence': 89,
#  'latitude': -36.2618,
#  'longitude': 141.8783,
#  'surface_temperature_celcius': 65}
# {'confidence': 90,
#  'latitude': -36.6828,
#  'longitude': 144.784,
#  'surface_temperature_celcius': 66}
# {'confidence': 89,
#  'latitude': -37.4843,
#  'longitude': 143.0592,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -37.7274,
#  'longitude': 142.9536,
#  'surface_temperature_celcius': 73}
# {'confidence': 91,
#  'latitude': -37.6964,
#  'longitude': 142.8583,
#  'surface_temperature_celcius': 69}
# {'confidence': 98,
#  'latitude': -38.0509,
#  'longitude': 143.9423,
#  'surface_temperature_celcius': 82}
# {'confidence': 92,
#  'latitude': -37.9284,
#  'longitude': 143.108,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.5701,
#  'longitude': 142.6497,
#  'surface_temperature_celcius': 94}
# {'confidence': 90,
#  'latitude': -36.7101,
#  'longitude': 142.3865,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -38.1693,
#  'longitude': 143.0466,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.7128,
#  'longitude': 142.3717,
#  'surface_temperature_celcius': 77}
# {'confidence': 97,
#  'latitude': -37.4885,
#  'longitude': 142.0658,
#  'surface_temperature_celcius': 81}
# {'confidence': 77,
#  'latitude': -36.7101,
#  'longitude': 142.981,
#  'surface_temperature_celcius': 68}
# {'confidence': 89,
#  'latitude': -37.0959,
#  'longitude': 143.8206,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.9594,
#  'longitude': 143.5638,
#  'surface_temperature_celcius': 87}
# {'confidence': 98,
#  'latitude': -36.5921,
#  'longitude': 144.4905,
#  'surface_temperature_celcius': 82}
# {'confidence': 96,
#  'latitude': -36.6787,
#  'longitude': 144.8042,
#  'surface_temperature_celcius': 79}
# {'confidence': 84,
#  'latitude': -38.0423,
#  'longitude': 146.4048,
#  'surface_temperature_celcius': 66}
# {'confidence': 94,
#  'latitude': -38.1224,
#  'longitude': 143.7553,
#  'surface_temperature_celcius': 73}
# {'confidence': 94,
#  'latitude': -38.0792,
#  'longitude': 143.7361,
#  'surface_temperature_celcius': 93}
# {'confidence': 93,
#  'latitude': -37.9157,
#  'longitude': 143.3544,
#  'surface_temperature_celcius': 72}
# {'confidence': 96,
#  'latitude': -37.7935,
#  'longitude': 143.1606,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -37.7756,
#  'longitude': 143.1388,
#  'surface_temperature_celcius': 67}
# {'confidence': 91,
#  'latitude': -37.7171,
#  'longitude': 142.9505,
#  'surface_temperature_celcius': 68}
# {'confidence': 94,
#  'latitude': -37.7236,
#  'longitude': 142.947,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -37.7002,
#  'longitude': 142.9562,
#  'surface_temperature_celcius': 89}
# {'confidence': 92,
#  'latitude': -37.6498,
#  'longitude': 142.5997,
#  'surface_temperature_celcius': 70}
# {'confidence': 100,
#  'latitude': -37.5728,
#  'longitude': 142.6348,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.4352,
#  'longitude': 143.1444,
#  'surface_temperature_celcius': 96}
# {'confidence': 92,
#  'latitude': -36.5828,
#  'longitude': 144.5775,
#  'surface_temperature_celcius': 70}
# {'confidence': 96,
#  'latitude': -36.5987,
#  'longitude': 144.4995,
#  'surface_temperature_celcius': 79}
# {'confidence': 98,
#  'latitude': -36.5262,
#  'longitude': 144.5737,
#  'surface_temperature_celcius': 84}
# {'confidence': 95,
#  'latitude': -36.6995,
#  'longitude': 142.97799999999998,
#  'surface_temperature_celcius': 76}
# {'confidence': 93,
#  'latitude': -36.8879,
#  'longitude': 141.6647,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -35.8768,
#  'longitude': 145.4627,
#  'surface_temperature_celcius': 86}
# {'confidence': 93,
#  'latitude': -36.4899,
#  'longitude': 142.2805,
#  'surface_temperature_celcius': 73}
# {'confidence': 93,
#  'latitude': -36.663000000000004,
#  'longitude': 141.3038,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -36.092,
#  'longitude': 141.7306,
#  'surface_temperature_celcius': 75}
# {'confidence': 89,
#  'latitude': -34.9023,
#  'longitude': 142.0557,
#  'surface_temperature_celcius': 65}
# {'confidence': 91,
#  'latitude': -36.2637,
#  'longitude': 145.3649,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -37.2609,
#  'longitude': 141.7999,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -36.91,
#  'longitude': 141.0704,
#  'surface_temperature_celcius': 73}
# {'confidence': 92,
#  'latitude': -36.2652,
#  'longitude': 145.3769,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -36.738,
#  'longitude': 142.1177,
#  'surface_temperature_celcius': 77}
# {'confidence': 89,
#  'latitude': -37.876,
#  'longitude': 143.7804,
#  'surface_temperature_celcius': 65}
# {'confidence': 88,
#  'latitude': -36.1546,
#  'longitude': 141.8146,
#  'surface_temperature_celcius': 74}
# {'confidence': 87,
#  'latitude': -37.9091,
#  'longitude': 143.5105,
#  'surface_temperature_celcius': 70}
# {'confidence': 80,
#  'latitude': -36.1559,
#  'longitude': 141.8102,
#  'surface_temperature_celcius': 66}
# {'confidence': 100,
#  'latitude': -37.9071,
#  'longitude': 143.53799999999998,
#  'surface_temperature_celcius': 88}
# {'confidence': 100,
#  'latitude': -37.3902,
#  'longitude': 148.2955,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -37.5027,
#  'longitude': 146.347,
#  'surface_temperature_celcius': 95}
# {'confidence': 100,
#  'latitude': -37.5043,
#  'longitude': 146.3299,
#  'surface_temperature_celcius': 93}
# {'confidence': 93,
#  'latitude': -36.1964,
#  'longitude': 144.5217,
#  'surface_temperature_celcius': 72}
# {'confidence': 93,
#  'latitude': -37.769,
#  'longitude': 147.94,
#  'surface_temperature_celcius': 72}
# {'confidence': 90,
#  'latitude': -36.1303,
#  'longitude': 146.3606,
#  'surface_temperature_celcius': 67}
# {'confidence': 98,
#  'latitude': -36.1345,
#  'longitude': 146.351,
#  'surface_temperature_celcius': 84}
# {'confidence': 99,
#  'latitude': -36.1586,
#  'longitude': 145.6666,
#  'surface_temperature_celcius': 85}
# {'confidence': 96,
#  'latitude': -36.5847,
#  'longitude': 145.1968,
#  'surface_temperature_celcius': 78}
# {'confidence': 93,
#  'latitude': -36.9111,
#  'longitude': 142.692,
#  'surface_temperature_celcius': 72}
# {'confidence': 99,
#  'latitude': -37.5115,
#  'longitude': 143.14,
#  'surface_temperature_celcius': 86}
# {'confidence': 86,
#  'latitude': -37.6775,
#  'longitude': 148.5131,
#  'surface_temperature_celcius': 78}
# {'confidence': 87,
#  'latitude': -36.3332,
#  'longitude': 145.8594,
#  'surface_temperature_celcius': 90}
# {'confidence': 70,
#  'latitude': -36.9303,
#  'longitude': 143.1034,
#  'surface_temperature_celcius': 72}
# {'confidence': 83,
#  'latitude': -36.3195,
#  'longitude': 146.0601,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.5839,
#  'longitude': 143.0588,
#  'surface_temperature_celcius': 99}
# {'confidence': 100,
#  'latitude': -36.5854,
#  'longitude': 143.0462,
#  'surface_temperature_celcius': 94}
# {'confidence': 95,
#  'latitude': -36.3014,
#  'longitude': 143.203,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -38.1917,
#  'longitude': 147.0745,
#  'surface_temperature_celcius': 94}
# {'confidence': 95,
#  'latitude': -38.1987,
#  'longitude': 147.0666,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -36.5454,
#  'longitude': 144.7402,
#  'surface_temperature_celcius': 96}
# {'confidence': 92,
#  'latitude': -36.7593,
#  'longitude': 142.895,
#  'surface_temperature_celcius': 69}
# {'confidence': 90,
#  'latitude': -36.3435,
#  'longitude': 141.5513,
#  'surface_temperature_celcius': 67}
# {'confidence': 93,
#  'latitude': -36.6942,
#  'longitude': 143.8021,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -36.3459,
#  'longitude': 141.5586,
#  'surface_temperature_celcius': 91}
# {'confidence': 93,
#  'latitude': -36.4046,
#  'longitude': 141.1534,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -36.0594,
#  'longitude': 141.5907,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -36.0576,
#  'longitude': 141.6122,
#  'surface_temperature_celcius': 94}
# {'confidence': 93,
#  'latitude': -36.388000000000005,
#  'longitude': 141.8309,
#  'surface_temperature_celcius': 73}
# {'confidence': 90,
#  'latitude': -36.094,
#  'longitude': 145.7646,
#  'surface_temperature_celcius': 67}
# {'confidence': 99,
#  'latitude': -36.5438,
#  'longitude': 144.7548,
#  'surface_temperature_celcius': 84}
# {'confidence': 95,
#  'latitude': -36.6537,
#  'longitude': 143.8781,
#  'surface_temperature_celcius': 76}
# {'confidence': 92,
#  'latitude': -36.663000000000004,
#  'longitude': 142.8567,
#  'surface_temperature_celcius': 71}
# {'confidence': 94,
#  'latitude': -37.6982,
#  'longitude': 143.0549,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.7187,
#  'longitude': 143.805,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -36.7742,
#  'longitude': 145.1991,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -36.5061,
#  'longitude': 144.5675,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.4035,
#  'longitude': 140.9935,
#  'surface_temperature_celcius': 95}
# {'confidence': 99,
#  'latitude': -36.4286,
#  'longitude': 141.1567,
#  'surface_temperature_celcius': 84}
# {'confidence': 91,
#  'latitude': -36.3635,
#  'longitude': 142.2809,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.664,
#  'longitude': 142.8802,
#  'surface_temperature_celcius': 87}
# {'confidence': 91,
#  'latitude': -36.6564,
#  'longitude': 142.8615,
#  'surface_temperature_celcius': 69}
# {'confidence': 93,
#  'latitude': -36.6657,
#  'longitude': 143.1675,
#  'surface_temperature_celcius': 72}
# {'confidence': 98,
#  'latitude': -36.8742,
#  'longitude': 142.7177,
#  'surface_temperature_celcius': 84}
# {'confidence': 91,
#  'latitude': -36.7751,
#  'longitude': 145.1696,
#  'surface_temperature_celcius': 68}
# {'confidence': 91,
#  'latitude': -36.3961,
#  'longitude': 140.9781,
#  'surface_temperature_celcius': 69}
# {'confidence': 100,
#  'latitude': -36.7708,
#  'longitude': 145.1908,
#  'surface_temperature_celcius': 98}
# {'confidence': 98,
#  'latitude': -37.758,
#  'longitude': 143.179,
#  'surface_temperature_celcius': 82}
# {'confidence': 94,
#  'latitude': -37.7609,
#  'longitude': 143.1633,
#  'surface_temperature_celcius': 74}
# {'confidence': 89,
#  'latitude': -36.5116,
#  'longitude': 144.562,
#  'surface_temperature_celcius': 66}
# {'confidence': 92,
#  'latitude': -36.803000000000004,
#  'longitude': 142.9261,
#  'surface_temperature_celcius': 70}
# {'confidence': 89,
#  'latitude': -36.4143,
#  'longitude': 143.27200000000002,
#  'surface_temperature_celcius': 65}
# {'confidence': 99,
#  'latitude': -36.7153,
#  'longitude': 143.8226,
#  'surface_temperature_celcius': 86}
# {'confidence': 100,
#  'latitude': -36.8791,
#  'longitude': 142.7261,
#  'surface_temperature_celcius': 93}
# {'confidence': 100,
#  'latitude': -36.7309,
#  'longitude': 142.3633,
#  'surface_temperature_celcius': 88}
# {'confidence': 92,
#  'latitude': -36.882,
#  'longitude': 142.7108,
#  'surface_temperature_celcius': 70}
# {'confidence': 93,
#  'latitude': -37.5135,
#  'longitude': 142.7238,
#  'surface_temperature_celcius': 72}
# {'confidence': 94,
#  'latitude': -36.2121,
#  'longitude': 144.6885,
#  'surface_temperature_celcius': 74}
# {'confidence': 97,
#  'latitude': -36.2206,
#  'longitude': 144.6856,
#  'surface_temperature_celcius': 80}
# {'confidence': 88,
#  'latitude': -38.0132,
#  'longitude': 146.5269,
#  'surface_temperature_celcius': 73}
# {'confidence': 87,
#  'latitude': -38.0148,
#  'longitude': 146.5413,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -37.8412,
#  'longitude': 147.2536,
#  'surface_temperature_celcius': 87}
# {'confidence': 96,
#  'latitude': -37.8429,
#  'longitude': 147.2691,
#  'surface_temperature_celcius': 78}
# {'confidence': 95,
#  'latitude': -36.6139,
#  'longitude': 143.501,
#  'surface_temperature_celcius': 77}
# {'confidence': 95,
#  'latitude': -37.9509,
#  'longitude': 143.9599,
#  'surface_temperature_celcius': 76}
# {'confidence': 97,
#  'latitude': -36.6224,
#  'longitude': 143.5092,
#  'surface_temperature_celcius': 80}
# {'confidence': 96,
#  'latitude': -38.0933,
#  'longitude': 143.9824,
#  'surface_temperature_celcius': 78}
# {'confidence': 91,
#  'latitude': -35.6138,
#  'longitude': 143.8666,
#  'surface_temperature_celcius': 68}
# {'confidence': 95,
#  'latitude': -36.0885,
#  'longitude': 145.0359,
#  'surface_temperature_celcius': 76}
# {'confidence': 96,
#  'latitude': -36.3193,
#  'longitude': 145.9162,
#  'surface_temperature_celcius': 78}
# {'confidence': 98,
#  'latitude': -36.0652,
#  'longitude': 146.0764,
#  'surface_temperature_celcius': 82}
# {'confidence': 100,
#  'latitude': -36.0682,
#  'longitude': 146.0602,
#  'surface_temperature_celcius': 90}
# {'confidence': 92,
#  'latitude': -37.7889,
#  'longitude': 143.1324,
#  'surface_temperature_celcius': 71}
# {'confidence': 93,
#  'latitude': -36.2306,
#  'longitude': 143.6408,
#  'surface_temperature_celcius': 72}
# {'confidence': 91,
#  'latitude': -36.4168,
#  'longitude': 141.6939,
#  'surface_temperature_celcius': 68}
# {'confidence': 97,
#  'latitude': -36.4211,
#  'longitude': 141.6875,
#  'surface_temperature_celcius': 81}
# {'confidence': 96,
#  'latitude': -36.8094,
#  'longitude': 142.8885,
#  'surface_temperature_celcius': 77}
# {'confidence': 84,
#  'latitude': -37.8323,
#  'longitude': 147.2232,
#  'surface_temperature_celcius': 68}
# {'confidence': 98,
#  'latitude': -38.2853,
#  'longitude': 145.9519,
#  'surface_temperature_celcius': 83}
# {'confidence': 98,
#  'latitude': -38.2375,
#  'longitude': 142.8363,
#  'surface_temperature_celcius': 82}
# {'confidence': 92,
#  'latitude': -37.4463,
#  'longitude': 142.7829,
#  'surface_temperature_celcius': 70}
# {'confidence': 95,
#  'latitude': -37.6854,
#  'longitude': 143.4543,
#  'surface_temperature_celcius': 76}
# {'confidence': 99,
#  'latitude': -38.0881,
#  'longitude': 143.9391,
#  'surface_temperature_celcius': 84}
# {'confidence': 96,
#  'latitude': -38.0866,
#  'longitude': 143.9534,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -38.2391,
#  'longitude': 142.82,
#  'surface_temperature_celcius': 71}
# {'confidence': 100,
#  'latitude': -38.5123,
#  'longitude': 146.4007,
#  'surface_temperature_celcius': 89}
# {'confidence': 96,
#  'latitude': -36.3438,
#  'longitude': 141.5832,
#  'surface_temperature_celcius': 78}
# {'confidence': 94,
#  'latitude': -37.4357,
#  'longitude': 142.7813,
#  'surface_temperature_celcius': 74}
# {'confidence': 99,
#  'latitude': -37.5867,
#  'longitude': 143.6256,
#  'surface_temperature_celcius': 85}
# {'confidence': 90,
#  'latitude': -36.2911,
#  'longitude': 141.1664,
#  'surface_temperature_celcius': 67}
# {'confidence': 96,
#  'latitude': -36.2842,
#  'longitude': 141.1741,
#  'surface_temperature_celcius': 79}
# {'confidence': 89,
#  'latitude': -36.7218,
#  'longitude': 141.6411,
#  'surface_temperature_celcius': 65}
# {'confidence': 84,
#  'latitude': -37.3656,
#  'longitude': 141.3903,
#  'surface_temperature_celcius': 78}
# {'confidence': 94,
#  'latitude': -36.4179,
#  'longitude': 144.2924,
#  'surface_temperature_celcius': 75}
# {'confidence': 92,
#  'latitude': -36.3207,
#  'longitude': 140.9737,
#  'surface_temperature_celcius': 70}
# {'confidence': 99,
#  'latitude': -36.2882,
#  'longitude': 141.1821,
#  'surface_temperature_celcius': 86}
# {'confidence': 91,
#  'latitude': -36.3153,
#  'longitude': 140.9789,
#  'surface_temperature_celcius': 69}
# {'confidence': 97,
#  'latitude': -36.4169,
#  'longitude': 144.2994,
#  'surface_temperature_celcius': 81}
# {'confidence': 93,
#  'latitude': -37.4671,
#  'longitude': 145.9962,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -36.3254,
#  'longitude': 144.3638,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.0816,
#  'longitude': 145.859,
#  'surface_temperature_celcius': 98}
# {'confidence': 100,
#  'latitude': -36.1532,
#  'longitude': 143.5527,
#  'surface_temperature_celcius': 90}
# {'confidence': 100,
#  'latitude': -36.0077,
#  'longitude': 141.7747,
#  'surface_temperature_celcius': 93}
# {'confidence': 94,
#  'latitude': -36.0828,
#  'longitude': 145.873,
#  'surface_temperature_celcius': 75}
# {'confidence': 91,
#  'latitude': -36.5541,
#  'longitude': 144.1321,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -35.6819,
#  'longitude': 143.5275,
#  'surface_temperature_celcius': 69}
# {'confidence': 90,
#  'latitude': -35.6871,
#  'longitude': 143.5235,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.1506,
#  'longitude': 143.5671,
#  'surface_temperature_celcius': 95}
# {'confidence': 93,
#  'latitude': -37.4984,
#  'longitude': 142.9739,
#  'surface_temperature_celcius': 73}
# {'confidence': 96,
#  'latitude': -37.253,
#  'longitude': 144.3681,
#  'surface_temperature_celcius': 78}
# {'confidence': 92,
#  'latitude': -36.9396,
#  'longitude': 143.1462,
#  'surface_temperature_celcius': 70}
# {'confidence': 96,
#  'latitude': -36.3387,
#  'longitude': 141.7542,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -36.3433,
#  'longitude': 143.4369,
#  'surface_temperature_celcius': 94}
# {'confidence': 100,
#  'latitude': -36.345,
#  'longitude': 143.4256,
#  'surface_temperature_celcius': 87}
# {'confidence': 90,
#  'latitude': -36.7032,
#  'longitude': 144.0992,
#  'surface_temperature_celcius': 66}
# {'confidence': 96,
#  'latitude': -36.3402,
#  'longitude': 141.7429,
#  'surface_temperature_celcius': 77}
# {'confidence': 89,
#  'latitude': -36.5661,
#  'longitude': 142.2956,
#  'surface_temperature_celcius': 65}
# {'confidence': 85,
#  'latitude': -36.5023,
#  'longitude': 143.6038,
#  'surface_temperature_celcius': 66}
# {'confidence': 90,
#  'latitude': -36.8616,
#  'longitude': 142.8025,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -38.0372,
#  'longitude': 146.0616,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -38.049,
#  'longitude': 146.0513,
#  'surface_temperature_celcius': 74}
# {'confidence': 89,
#  'latitude': -35.4666,
#  'longitude': 142.0749,
#  'surface_temperature_celcius': 65}
# {'confidence': 95,
#  'latitude': -36.0396,
#  'longitude': 141.7183,
#  'surface_temperature_celcius': 76}
# {'confidence': 94,
#  'latitude': -36.2775,
#  'longitude': 146.1026,
#  'surface_temperature_celcius': 74}
# {'confidence': 100,
#  'latitude': -38.0361,
#  'longitude': 146.0567,
#  'surface_temperature_celcius': 90}
# {'confidence': 91,
#  'latitude': -36.7746,
#  'longitude': 146.6642,
#  'surface_temperature_celcius': 68}
# {'confidence': 96,
#  'latitude': -36.8359,
#  'longitude': 146.6448,
#  'surface_temperature_celcius': 78}
# {'confidence': 98,
#  'latitude': -37.9085,
#  'longitude': 141.1038,
#  'surface_temperature_celcius': 82}
# {'confidence': 100,
#  'latitude': -38.4349,
#  'longitude': 146.3122,
#  'surface_temperature_celcius': 93}
# {'confidence': 89,
#  'latitude': -38.4792,
#  'longitude': 146.3081,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.9047,
#  'longitude': 141.0945,
#  'surface_temperature_celcius': 90}
# {'confidence': 91,
#  'latitude': -36.7685,
#  'longitude': 142.7134,
#  'surface_temperature_celcius': 69}
# {'confidence': 91,
#  'latitude': -36.7801,
#  'longitude': 142.7151,
#  'surface_temperature_celcius': 68}
# {'confidence': 96,
#  'latitude': -36.1002,
#  'longitude': 142.3405,
#  'surface_temperature_celcius': 78}
# {'confidence': 90,
#  'latitude': -36.4325,
#  'longitude': 144.3142,
#  'surface_temperature_celcius': 67}
# {'confidence': 94,
#  'latitude': -36.2693,
#  'longitude': 143.1768,
#  'surface_temperature_celcius': 85}
# {'confidence': 91,
#  'latitude': -36.3774,
#  'longitude': 143.7079,
#  'surface_temperature_celcius': 68}
# {'confidence': 100,
#  'latitude': -36.3756,
#  'longitude': 143.7243,
#  'surface_temperature_celcius': 88}
# {'confidence': 97,
#  'latitude': -36.369,
#  'longitude': 143.7132,
#  'surface_temperature_celcius': 80}
# {'confidence': 100,
#  'latitude': -36.3799,
#  'longitude': 143.7149,
#  'surface_temperature_celcius': 89}
# {'confidence': 91,
#  'latitude': -37.8644,
#  'longitude': 143.4263,
#  'surface_temperature_celcius': 69}
# {'confidence': 89,
#  'latitude': -38.3998,
#  'longitude': 147.064,
#  'surface_temperature_celcius': 65}
# {'confidence': 94,
#  'latitude': -37.4796,
#  'longitude': 141.9403,
#  'surface_temperature_celcius': 87}
# {'confidence': 58,
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
# {'confidence': 62,
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'confidence': 100,
#  'latitude': -37.396,
#  'longitude': 148.086,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.399,
#  'longitude': 148.08100000000002,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -37.400999999999996,
#  'longitude': 148.067,
#  'surface_temperature_celcius': 79}
# {'confidence': 100,
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'surface_temperature_celcius': 88}
# {'confidence': 68,
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'confidence': 64,
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'confidence': 86,
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'surface_temperature_celcius': 76}
# {'confidence': 73,
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'surface_temperature_celcius': 66}
# {'confidence': 61,
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'confidence': 100,
#  'latitude': -37.461999999999996,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 90}
# {'confidence': 88,
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'confidence': 96,
#  'latitude': -38.126999999999995,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'confidence': 100,
#  'latitude': -37.294000000000004,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'confidence': 90,
#  'latitude': -37.330999999999996,
#  'longitude': 143.122,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'surface_temperature_celcius': 93}
# {'confidence': 96,
#  'latitude': -37.475,
#  'longitude': 143.365,
#  'surface_temperature_celcius': 77}
# {'confidence': 97,
#  'latitude': -37.69,
#  'longitude': 143.605,
#  'surface_temperature_celcius': 80}
# {'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'confidence': 87,
#  'latitude': -37.861999999999995,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.35399999999998,
#  'surface_temperature_celcius': 73}
# {'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.30700000000002,
#  'surface_temperature_celcius': 80}
# {'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'confidence': 100,
#  'latitude': -37.641999999999996,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.30200000000002,
#  'surface_temperature_celcius': 83}
# {'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'confidence': 100,
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'surface_temperature_celcius': 71}
# {'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'confidence': 93,
#  'latitude': -38.056999999999995,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.05100000000002,
#  'surface_temperature_celcius': 68}
# {'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}

# %% [markdown]
# #### c) Find date, surface temperature (°C), air temperature (°C), relative humidity and max wind speed on 15th and 16th of December 2021

# %%
target_date_1 = '15-12-2021'
target_date_obj_1 = datetime.strptime(target_date_1, '%d-%m-%Y') # convert the string to date object

target_date_2 = '16-12-2021'
target_date_obj_2 = datetime.strptime(target_date_2, '%d-%m-%Y') # convert the string to date object

cursor = db.embedded_climate_hotspot.find(
    { "$or": [ { "date": target_date_obj_1 }, { "date": target_date_obj_2 } ] },
    # only output the necessary details
    {"date":1,"hotspots.surface_temperature_celcius":1,"air_temperature_celcius":1,\
     "relative_humidity":1,"max_wind_speed":1,"_id":0}
)

"""
How to interpret my output:
The "hotspots" array contains all the surface temperature values for hotspots on 15th and 16th Decemeber 2021.
"""

for document in cursor: 
    document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
    pprint(document)
# Out:
# {'air_temperature_celcius': 18,
#  'date': '15-12-2021',
#  'hotspots': [{'surface_temperature_celcius': 42},
#               {'surface_temperature_celcius': 36},
#               {'surface_temperature_celcius': 38},
#               {'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18,
#  'date': '16-12-2021',
#  'hotspots': [{'surface_temperature_celcius': 43},
#               {'surface_temperature_celcius': 33},
#               {'surface_temperature_celcius': 54},
#               {'surface_temperature_celcius': 73},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 75},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 66},
#               {'surface_temperature_celcius': 56},
#               {'surface_temperature_celcius': 60},
#               {'surface_temperature_celcius': 73},
#               {'surface_temperature_celcius': 48},
#               {'surface_temperature_celcius': 55},
#               {'surface_temperature_celcius': 64},
#               {'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %% [markdown]
# #### d) Find datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.

# %%
cursor = db.embedded_climate_hotspot.aggregate([
    # since necessary details are in an associative array, hence I need to use unwind
    {"$unwind":"$hotspots"},
    # make sure the confidence was between 80 and 100 inclusive
    {"$match": {"$and":[{"hotspots.confidence":{"$gt":79}},\
                        {"hotspots.confidence":{"$lt":101}}]}},
    # only output the necessary details
    {"$project":{"hotspots.datetime":1,"air_temperature_celcius":1,"hotspots.surface_temperature_celcius":1,\
                 "hotspots.confidence":1,"_id":0}}
])

for document in cursor:
    # make the datetime more readable
    document['hotspots']['datetime'] = document['hotspots']['datetime'].strftime("%d-%m-%Y, %H:%M:%S")
    pprint(document)
# Out:
# {'air_temperature_celcius': 20,
#  'hotspots': {'confidence': 87,
#               'datetime': '06-03-2021, 05:06:30',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 20,
#  'hotspots': {'confidence': 85,
#               'datetime': '06-03-2021, 05:06:20',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 88,
#               'datetime': '07-03-2021, 04:16:10',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 86,
#               'datetime': '09-03-2021, 13:23:40',
#               'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '10-03-2021, 04:48:40',
#               'surface_temperature_celcius': 105}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '10-03-2021, 04:46:20',
#               'surface_temperature_celcius': 109}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': '10-03-2021, 04:45:30',
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 97,
#               'datetime': '10-03-2021, 04:45:30',
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': '10-03-2021, 04:43:50',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 94,
#               'datetime': '12-03-2021, 04:33:50',
#               'surface_temperature_celcius': 105}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 84,
#               'datetime': '12-03-2021, 04:29:50',
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 100,
#               'datetime': '12-03-2021, 04:28:20',
#               'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 80,
#               'datetime': '12-03-2021, 04:28:00',
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 85,
#               'datetime': '12-03-2021, 04:27:20',
#               'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 90,
#               'datetime': '14-03-2021, 04:24:40',
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 93,
#               'datetime': '14-03-2021, 04:22:20',
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 90,
#               'datetime': '14-03-2021, 04:20:50',
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 95,
#               'datetime': '14-03-2021, 04:16:30',
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 89,
#               'datetime': '14-03-2021, 04:16:20',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 81,
#               'datetime': '14-03-2021, 04:14:40',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 96,
#               'datetime': '14-03-2021, 04:14:30',
#               'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 25,
#  'hotspots': {'confidence': 94,
#               'datetime': '14-03-2021, 04:14:30',
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 94,
#               'datetime': '17-03-2021, 04:48:20',
#               'surface_temperature_celcius': 74}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 84,
#               'datetime': '17-03-2021, 04:45:10',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 86,
#               'datetime': '17-03-2021, 04:45:00',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 100,
#               'datetime': '18-03-2021, 03:50:50',
#               'surface_temperature_celcius': 121}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 97,
#               'datetime': '18-03-2021, 03:50:40',
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 85,
#               'datetime': '19-03-2021, 04:39:50',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 96,
#               'datetime': '19-03-2021, 04:39:20',
#               'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 90,
#               'datetime': '19-03-2021, 04:36:00',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 98,
#               'datetime': '19-03-2021, 04:33:00',
#               'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 100,
#               'datetime': '19-03-2021, 04:32:50',
#               'surface_temperature_celcius': 91}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 84,
#               'datetime': '19-03-2021, 04:32:50',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 100,
#               'datetime': '19-03-2021, 04:32:40',
#               'surface_temperature_celcius': 113}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 92,
#               'datetime': '19-03-2021, 04:32:40',
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 100,
#               'datetime': '19-03-2021, 04:32:40',
#               'surface_temperature_celcius': 106}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 82,
#               'datetime': '25-03-2021, 03:59:50',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 87,
#               'datetime': '25-03-2021, 03:58:10',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 95,
#               'datetime': '25-03-2021, 03:58:10',
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 85,
#               'datetime': '25-03-2021, 03:57:10',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 100,
#               'datetime': '25-03-2021, 03:57:10',
#               'surface_temperature_celcius': 111}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 95,
#               'datetime': '25-03-2021, 03:57:10',
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 100,
#               'datetime': '25-03-2021, 03:56:40',
#               'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 81,
#               'datetime': '26-03-2021, 04:43:20',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 80,
#               'datetime': '26-03-2021, 04:40:50',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 81,
#               'datetime': '26-03-2021, 04:39:50',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 91,
#               'datetime': '26-03-2021, 04:39:10',
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 92,
#               'datetime': '26-03-2021, 04:39:10',
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 100,
#               'datetime': '26-03-2021, 04:39:10',
#               'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 82,
#               'datetime': '26-03-2021, 04:39:10',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 87,
#               'datetime': '26-03-2021, 04:39:10',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 84,
#               'datetime': '26-03-2021, 04:39:10',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 88,
#               'datetime': '28-03-2021, 04:38:00',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 86,
#               'datetime': '28-03-2021, 04:33:40',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 92,
#               'datetime': '28-03-2021, 04:33:30',
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 95,
#               'datetime': '28-03-2021, 04:33:30',
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 93,
#               'datetime': '28-03-2021, 04:32:20',
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 83,
#               'datetime': '28-03-2021, 04:30:50',
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 80,
#               'datetime': '28-03-2021, 04:30:20',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 94,
#               'datetime': '28-03-2021, 04:30:10',
#               'surface_temperature_celcius': 74}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 98,
#               'datetime': '28-03-2021, 04:30:10',
#               'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 81,
#               'datetime': '28-03-2021, 04:30:10',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 97,
#               'datetime': '28-03-2021, 04:30:10',
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 81,
#               'datetime': '28-03-2021, 04:28:30',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 88,
#               'datetime': '28-03-2021, 04:28:30',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 87,
#               'datetime': '28-03-2021, 04:28:30',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 97,
#               'datetime': '28-03-2021, 04:27:40',
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 100,
#               'datetime': '28-03-2021, 04:27:20',
#               'surface_temperature_celcius': 107}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 100,
#               'datetime': '28-03-2021, 04:27:10',
#               'surface_temperature_celcius': 108}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 82,
#               'datetime': '28-03-2021, 04:27:00',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 99,
#               'datetime': '28-03-2021, 04:27:00',
#               'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 81,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 80,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 83,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 100,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 87,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 97,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 85,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 88,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 87,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 84,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 97,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 83,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 85,
#               'datetime': '28-03-2021, 04:26:50',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 82,
#               'datetime': '31-03-2021, 05:07:10',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 87,
#               'datetime': '31-03-2021, 05:01:20',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 82,
#               'datetime': '31-03-2021, 04:58:30',
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 80,
#               'datetime': '31-03-2021, 04:58:00',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 86,
#               'datetime': '31-03-2021, 04:57:10',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 81,
#               'datetime': '31-03-2021, 00:36:30',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 91,
#               'datetime': '03-04-2021, 13:17:00',
#               'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 83,
#               'datetime': '03-04-2021, 13:15:30',
#               'surface_temperature_celcius': 40}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '03-04-2021, 13:15:10',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 96,
#               'datetime': '03-04-2021, 13:15:10',
#               'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 87,
#               'datetime': '03-04-2021, 03:59:10',
#               'surface_temperature_celcius': 96}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 93,
#               'datetime': '03-04-2021, 03:57:50',
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 82,
#               'datetime': '03-04-2021, 03:56:20',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 88,
#               'datetime': '03-04-2021, 03:55:10',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 95,
#               'datetime': '03-04-2021, 03:55:10',
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 96,
#               'datetime': '03-04-2021, 03:54:00',
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '03-04-2021, 03:53:50',
#               'surface_temperature_celcius': 93}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 85,
#               'datetime': '03-04-2021, 03:53:30',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 84,
#               'datetime': '03-04-2021, 03:52:30',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '03-04-2021, 03:52:30',
#               'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '03-04-2021, 03:52:20',
#               'surface_temperature_celcius': 115}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 86,
#               'datetime': '03-04-2021, 03:52:10',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '03-04-2021, 03:52:10',
#               'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '03-04-2021, 03:52:10',
#               'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 85,
#               'datetime': '03-04-2021, 03:52:10',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 83,
#               'datetime': '03-04-2021, 03:51:30',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 89,
#               'datetime': '03-04-2021, 03:51:30',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 87,
#               'datetime': '03-04-2021, 03:51:10',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 81,
#               'datetime': '03-04-2021, 03:51:00',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 98,
#               'datetime': '03-04-2021, 03:51:00',
#               'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 80,
#               'datetime': '03-04-2021, 03:51:00',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '03-04-2021, 03:51:00',
#               'surface_temperature_celcius': 103}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 87,
#               'datetime': '03-04-2021, 03:50:50',
#               'surface_temperature_celcius': 97}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 90,
#               'datetime': '03-04-2021, 03:50:50',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 85,
#               'datetime': '03-04-2021, 03:50:40',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 99,
#               'datetime': '03-04-2021, 03:50:40',
#               'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 93,
#               'datetime': '03-04-2021, 03:50:40',
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 95,
#               'datetime': '03-04-2021, 03:50:40',
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 86,
#               'datetime': '03-04-2021, 03:50:40',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 89,
#               'datetime': '03-04-2021, 03:50:40',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 82,
#               'datetime': '03-04-2021, 03:50:40',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 89,
#               'datetime': '03-04-2021, 03:50:40',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 81,
#               'datetime': '03-04-2021, 01:07:20',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 93,
#               'datetime': '04-04-2021, 15:31:00',
#               'surface_temperature_celcius': 44}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 15:30:40',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 88,
#               'datetime': '04-04-2021, 04:41:50',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': '04-04-2021, 04:41:10',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 88,
#               'datetime': '04-04-2021, 04:41:00',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 86,
#               'datetime': '04-04-2021, 04:41:00',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:40:00',
#               'surface_temperature_celcius': 120}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 90,
#               'datetime': '04-04-2021, 04:39:50',
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 85,
#               'datetime': '04-04-2021, 04:39:50',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 90,
#               'datetime': '04-04-2021, 04:39:40',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 81,
#               'datetime': '04-04-2021, 04:39:40',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:39:20',
#               'surface_temperature_celcius': 107}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 88,
#               'datetime': '04-04-2021, 04:37:10',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 88,
#               'datetime': '04-04-2021, 04:36:10',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 87,
#               'datetime': '04-04-2021, 04:36:10',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 90,
#               'datetime': '04-04-2021, 04:36:00',
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:35:00',
#               'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 83,
#               'datetime': '04-04-2021, 04:34:50',
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 89,
#               'datetime': '04-04-2021, 04:34:20',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 96,
#               'datetime': '04-04-2021, 04:34:20',
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 85,
#               'datetime': '04-04-2021, 04:34:20',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 84,
#               'datetime': '04-04-2021, 04:34:00',
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 92,
#               'datetime': '04-04-2021, 04:33:50',
#               'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 81,
#               'datetime': '04-04-2021, 04:33:40',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:33:30',
#               'surface_temperature_celcius': 113}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 80,
#               'datetime': '04-04-2021, 04:33:30',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 85,
#               'datetime': '04-04-2021, 04:33:30',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': '04-04-2021, 04:33:10',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': '04-04-2021, 04:33:10',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 97,
#               'datetime': '04-04-2021, 04:33:00',
#               'surface_temperature_celcius': 79}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 86,
#               'datetime': '04-04-2021, 04:33:00',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 98,
#               'datetime': '04-04-2021, 04:32:50',
#               'surface_temperature_celcius': 82}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 85,
#               'datetime': '04-04-2021, 04:32:50',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 84,
#               'datetime': '04-04-2021, 04:32:50',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': '04-04-2021, 04:32:50',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:32:50',
#               'surface_temperature_celcius': 123}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 82,
#               'datetime': '04-04-2021, 04:32:50',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:32:50',
#               'surface_temperature_celcius': 118}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 80,
#               'datetime': '04-04-2021, 04:32:40',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 96,
#               'datetime': '04-04-2021, 04:32:40',
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 93,
#               'datetime': '04-04-2021, 04:32:40',
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:32:40',
#               'surface_temperature_celcius': 120}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 87,
#               'datetime': '04-04-2021, 04:32:40',
#               'surface_temperature_celcius': 92}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:32:40',
#               'surface_temperature_celcius': 101}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 81,
#               'datetime': '04-04-2021, 04:32:40',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 100,
#               'datetime': '04-04-2021, 04:32:40',
#               'surface_temperature_celcius': 98}}
# {'air_temperature_celcius': 16,
#  'hotspots': {'confidence': 80,
#               'datetime': '04-04-2021, 00:12:50',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': '05-04-2021, 13:09:00',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 81,
#               'datetime': '05-04-2021, 13:09:00',
#               'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 93,
#               'datetime': '05-04-2021, 13:08:40',
#               'surface_temperature_celcius': 44}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': '05-04-2021, 13:08:40',
#               'surface_temperature_celcius': 47}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 82,
#               'datetime': '05-04-2021, 13:07:00',
#               'surface_temperature_celcius': 40}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': '05-04-2021, 13:04:20',
#               'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': '05-04-2021, 13:03:20',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 98,
#               'datetime': '05-04-2021, 13:03:00',
#               'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': '05-04-2021, 13:03:00',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 81,
#               'datetime': '05-04-2021, 13:03:00',
#               'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 88,
#               'datetime': '05-04-2021, 13:02:40',
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 80,
#               'datetime': '05-04-2021, 13:02:40',
#               'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 87,
#               'datetime': '05-04-2021, 05:16:50',
#               'surface_temperature_celcius': 88}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 93,
#               'datetime': '05-04-2021, 05:15:30',
#               'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 93,
#               'datetime': '05-04-2021, 03:40:50',
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 95,
#               'datetime': '05-04-2021, 03:40:30',
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 81,
#               'datetime': '05-04-2021, 03:40:20',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 89,
#               'datetime': '05-04-2021, 03:39:30',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 82,
#               'datetime': '05-04-2021, 03:39:30',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 90,
#               'datetime': '05-04-2021, 03:39:20',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 83,
#               'datetime': '05-04-2021, 03:39:20',
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 89,
#               'datetime': '05-04-2021, 03:39:10',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 83,
#               'datetime': '05-04-2021, 03:39:10',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 95,
#               'datetime': '05-04-2021, 03:39:10',
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 100,
#               'datetime': '05-04-2021, 03:39:10',
#               'surface_temperature_celcius': 92}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 88,
#               'datetime': '05-04-2021, 03:39:10',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 89,
#               'datetime': '05-04-2021, 03:39:10',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 97,
#               'datetime': '06-04-2021, 13:45:30',
#               'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 84,
#               'datetime': '06-04-2021, 04:32:20',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 92,
#               'datetime': '06-04-2021, 04:31:10',
#               'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '06-04-2021, 04:27:50',
#               'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '06-04-2021, 04:27:50',
#               'surface_temperature_celcius': 88}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': '06-04-2021, 04:27:10',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '06-04-2021, 04:27:00',
#               'surface_temperature_celcius': 97}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 86,
#               'datetime': '06-04-2021, 04:27:00',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': '06-04-2021, 04:27:00',
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '06-04-2021, 04:27:00',
#               'surface_temperature_celcius': 99}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': '06-04-2021, 04:27:00',
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': '06-04-2021, 04:24:40',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 89,
#               'datetime': '06-04-2021, 04:24:20',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 89,
#               'datetime': '06-04-2021, 04:24:20',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 89,
#               'datetime': '06-04-2021, 04:24:00',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 92,
#               'datetime': '06-04-2021, 04:23:50',
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 99,
#               'datetime': '06-04-2021, 04:23:50',
#               'surface_temperature_celcius': 85}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 93,
#               'datetime': '06-04-2021, 04:23:30',
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 89,
#               'datetime': '06-04-2021, 04:23:10',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 87,
#               'datetime': '06-04-2021, 04:23:00',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': '06-04-2021, 04:22:40',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': '06-04-2021, 04:22:20',
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': '06-04-2021, 04:22:20',
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': '06-04-2021, 04:22:20',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '06-04-2021, 04:22:20',
#               'surface_temperature_celcius': 103}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 91,
#               'datetime': '06-04-2021, 04:22:20',
#               'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 86,
#               'datetime': '06-04-2021, 04:22:10',
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': '06-04-2021, 04:22:10',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': '06-04-2021, 04:22:10',
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': '06-04-2021, 04:21:30',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': '06-04-2021, 04:21:10',
#               'surface_temperature_celcius': 96}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '06-04-2021, 04:21:00',
#               'surface_temperature_celcius': 115}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 84,
#               'datetime': '06-04-2021, 04:21:00',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '06-04-2021, 04:20:50',
#               'surface_temperature_celcius': 95}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 88,
#               'datetime': '06-04-2021, 04:20:50',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': '06-04-2021, 04:20:50',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 83,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 96,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 91,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 97,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 81}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 82,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 104}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 92,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 87,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 87,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 84,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 87,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 100}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 86,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 72}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 81,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 94,
#               'datetime': '06-04-2021, 04:20:40',
#               'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 85,
#               'datetime': '07-04-2021, 12:56:50',
#               'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 80,
#               'datetime': '07-04-2021, 12:56:30',
#               'surface_temperature_celcius': 39}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 94,
#               'datetime': '07-04-2021, 12:56:30',
#               'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 86,
#               'datetime': '07-04-2021, 12:53:40',
#               'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 86,
#               'datetime': '07-04-2021, 12:52:10',
#               'surface_temperature_celcius': 41}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 97,
#               'datetime': '07-04-2021, 12:51:20',
#               'surface_temperature_celcius': 45}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 100,
#               'datetime': '07-04-2021, 12:51:00',
#               'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 92,
#               'datetime': '07-04-2021, 12:50:50',
#               'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 89,
#               'datetime': '07-04-2021, 12:50:40',
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 80,
#               'datetime': '07-04-2021, 05:09:50',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 80,
#               'datetime': '07-04-2021, 05:03:10',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 81,
#               'datetime': '07-04-2021, 05:03:10',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 100,
#               'datetime': '07-04-2021, 03:31:40',
#               'surface_temperature_celcius': 89}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 96,
#               'datetime': '07-04-2021, 03:28:20',
#               'surface_temperature_celcius': 78}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 92,
#               'datetime': '07-04-2021, 03:27:30',
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 92,
#               'datetime': '07-04-2021, 03:27:20',
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 95,
#               'datetime': '07-04-2021, 03:27:20',
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 21,
#  'hotspots': {'confidence': 100,
#               'datetime': '07-04-2021, 03:27:10',
#               'surface_temperature_celcius': 106}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 99,
#               'datetime': '08-04-2021, 04:14:00',
#               'surface_temperature_celcius': 85}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 91,
#               'datetime': '08-04-2021, 04:12:50',
#               'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 100,
#               'datetime': '08-04-2021, 04:12:20',
#               'surface_temperature_celcius': 94}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': '08-04-2021, 04:12:00',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 98,
#               'datetime': '08-04-2021, 04:08:50',
#               'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 90,
#               'datetime': '08-04-2021, 04:08:30',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': '08-04-2021, 04:08:30',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': '08-04-2021, 04:08:30',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': '08-04-2021, 04:08:30',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 81,
#               'datetime': '11-04-2021, 04:39:20',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 84,
#               'datetime': '11-04-2021, 04:39:00',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 85,
#               'datetime': '11-04-2021, 04:39:00',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 93,
#               'datetime': '12-04-2021, 13:15:10',
#               'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 100,
#               'datetime': '12-04-2021, 05:28:10',
#               'surface_temperature_celcius': 106}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 84,
#               'datetime': '12-04-2021, 05:28:00',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 94,
#               'datetime': '12-04-2021, 05:21:40',
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 14,
# ...
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 12,
#  'hotspots': {'confidence': 84,
#               'datetime': '01-10-2021, 04:10:28',
#               'surface_temperature_celcius': 52}}
# {'air_temperature_celcius': 12,
#  'hotspots': {'confidence': 89,
#               'datetime': '01-10-2021, 04:10:28',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 11,
#  'hotspots': {'confidence': 83,
#               'datetime': '02-10-2021, 04:53:10',
#               'surface_temperature_celcius': 50}}
# {'air_temperature_celcius': 11,
#  'hotspots': {'confidence': 85,
#               'datetime': '02-10-2021, 04:53:09',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 92,
#               'datetime': '03-10-2021, 13:23:43',
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 90,
#               'datetime': '03-10-2021, 03:58:15',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 81,
#               'datetime': '03-10-2021, 03:58:15',
#               'surface_temperature_celcius': 48}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 82,
#               'datetime': '03-10-2021, 03:58:15',
#               'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 84,
#               'datetime': '03-10-2021, 03:58:15',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 90,
#               'datetime': '03-10-2021, 03:58:15',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 100,
#               'datetime': '03-10-2021, 03:58:14',
#               'surface_temperature_celcius': 90}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 88,
#               'datetime': '03-10-2021, 03:58:14',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 87,
#               'datetime': '03-10-2021, 03:58:14',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': '04-10-2021, 04:41:02',
#               'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 80,
#               'datetime': '04-10-2021, 04:41:00',
#               'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 85,
#               'datetime': '04-10-2021, 04:41:00',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 19,
#  'hotspots': {'confidence': 88,
#               'datetime': '04-10-2021, 04:41:00',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 91,
#               'datetime': '07-10-2021, 12:59:33',
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 96,
#               'datetime': '10-10-2021, 04:04:19',
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 100,
#               'datetime': '15-10-2021, 04:23:01',
#               'surface_temperature_celcius': 87}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 99,
#               'datetime': '15-10-2021, 04:23:01',
#               'surface_temperature_celcius': 85}}
# {'air_temperature_celcius': 22,
#  'hotspots': {'confidence': 94,
#               'datetime': '17-10-2021, 13:36:12',
#               'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 22,
#  'hotspots': {'confidence': 91,
#               'datetime': '17-10-2021, 04:10:45',
#               'surface_temperature_celcius': 68}}
# {'air_temperature_celcius': 22,
#  'hotspots': {'confidence': 82,
#               'datetime': '17-10-2021, 04:10:32',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 84,
#               'datetime': '18-10-2021, 00:39:02',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 82,
#               'datetime': '18-10-2021, 00:39:02',
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 80,
#               'datetime': '20-10-2021, 04:41:19',
#               'surface_temperature_celcius': 46}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 82,
#               'datetime': '20-10-2021, 04:41:19',
#               'surface_temperature_celcius': 50}}
# {'air_temperature_celcius': 12,
#  'hotspots': {'confidence': 88,
#               'datetime': '21-10-2021, 01:09:55',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 12,
#  'hotspots': {'confidence': 92,
#               'datetime': '21-10-2021, 01:09:54',
#               'surface_temperature_celcius': 67}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 100,
#               'datetime': '26-10-2021, 13:30:31',
#               'surface_temperature_celcius': 48}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 100,
#               'datetime': '26-10-2021, 13:30:31',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 22,
#  'hotspots': {'confidence': 86,
#               'datetime': '27-10-2021, 04:47:31',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 81,
#               'datetime': '28-10-2021, 03:52:17',
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 83,
#               'datetime': '05-11-2021, 04:41:34',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 90,
#               'datetime': '05-11-2021, 04:41:19',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 13,
#  'hotspots': {'confidence': 89,
#               'datetime': '05-11-2021, 04:41:19',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 85,
#               'datetime': '09-11-2021, 04:16:48',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 100,
#               'datetime': '09-11-2021, 04:16:48',
#               'surface_temperature_celcius': 93}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 96,
#               'datetime': '09-11-2021, 04:16:48',
#               'surface_temperature_celcius': 77}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 87,
#               'datetime': '09-11-2021, 04:16:44',
#               'surface_temperature_celcius': 62}}
# {'air_temperature_celcius': 14,
#  'hotspots': {'confidence': 97,
#               'datetime': '09-11-2021, 04:16:44',
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 80,
#               'datetime': '11-11-2021, 13:30:08',
#               'surface_temperature_celcius': 37}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 100,
#               'datetime': '11-11-2021, 13:30:08',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 86,
#               'datetime': '11-11-2021, 04:04:25',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 89,
#               'datetime': '12-11-2021, 00:33:15',
#               'surface_temperature_celcius': 69}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 87,
#               'datetime': '13-11-2021, 03:52:15',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 81,
#               'datetime': '13-11-2021, 03:52:14',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 87,
#               'datetime': '14-11-2021, 04:35:04',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 85,
#               'datetime': '21-11-2021, 00:27:21',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 84,
#               'datetime': '22-11-2021, 03:46:00',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 23,
#  'hotspots': {'confidence': 88,
#               'datetime': '22-11-2021, 03:46:00',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 84,
#               'datetime': '23-11-2021, 04:28:59',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 24,
#  'hotspots': {'confidence': 93,
#               'datetime': '23-11-2021, 04:28:59',
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 100,
#               'datetime': '29-11-2021, 13:17:24',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 100,
#               'datetime': '29-11-2021, 03:52:10',
#               'surface_temperature_celcius': 87}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 97,
#               'datetime': '29-11-2021, 03:52:10',
#               'surface_temperature_celcius': 80}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 99,
#               'datetime': '29-11-2021, 03:52:10',
#               'surface_temperature_celcius': 84}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': '30-11-2021, 15:38:36',
#               'surface_temperature_celcius': 53}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': '30-11-2021, 15:38:35',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': '30-11-2021, 15:38:35',
#               'surface_temperature_celcius': 49}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 84,
#               'datetime': '30-11-2021, 12:22:15',
#               'surface_temperature_celcius': 38}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 81,
#               'datetime': '30-11-2021, 12:22:15',
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': '30-11-2021, 12:22:15',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': '30-11-2021, 12:22:15',
#               'surface_temperature_celcius': 65}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 100,
#               'datetime': '30-11-2021, 12:22:14',
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 84,
#               'datetime': '30-11-2021, 04:35:00',
#               'surface_temperature_celcius': 59}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 98,
#               'datetime': '30-11-2021, 04:34:57',
#               'surface_temperature_celcius': 83}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 81,
#               'datetime': '30-11-2021, 04:34:57',
#               'surface_temperature_celcius': 57}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 84,
#               'datetime': '30-11-2021, 04:34:57',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 99,
#               'datetime': '30-11-2021, 04:34:57',
#               'surface_temperature_celcius': 86}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 83,
#               'datetime': '30-11-2021, 00:20:53',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 87,
#               'datetime': '30-11-2021, 00:20:53',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 95,
#               'datetime': '30-11-2021, 00:20:53',
#               'surface_temperature_celcius': 76}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 81,
#               'datetime': '30-11-2021, 00:20:53',
#               'surface_temperature_celcius': 56}}
# {'air_temperature_celcius': 26,
#  'hotspots': {'confidence': 81,
#               'datetime': '30-11-2021, 00:20:53',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '08-12-2021, 13:11:44',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '08-12-2021, 13:11:44',
#               'surface_temperature_celcius': 71}}
# {'air_temperature_celcius': 15,
#  'hotspots': {'confidence': 100,
#               'datetime': '08-12-2021, 13:11:43',
#               'surface_temperature_celcius': 52}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 87,
#               'datetime': '09-12-2021, 00:14:34',
#               'surface_temperature_celcius': 61}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 81,
#               'datetime': '09-12-2021, 00:14:34',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 84,
#               'datetime': '09-12-2021, 00:14:33',
#               'surface_temperature_celcius': 58}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 86,
#               'datetime': '09-12-2021, 00:14:33',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 83,
#               'datetime': '13-12-2021, 04:04:19',
#               'surface_temperature_celcius': 60}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 92,
#               'datetime': '14-12-2021, 04:47:25',
#               'surface_temperature_celcius': 70}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 92,
#               'datetime': '15-12-2021, 13:17:17',
#               'surface_temperature_celcius': 42}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 94,
#               'datetime': '16-12-2021, 15:38:39',
#               'surface_temperature_celcius': 43}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 93,
#               'datetime': '16-12-2021, 04:35:13',
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 84,
#               'datetime': '16-12-2021, 04:34:58',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 95,
#               'datetime': '16-12-2021, 04:34:58',
#               'surface_temperature_celcius': 75}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 90,
#               'datetime': '16-12-2021, 04:34:57',
#               'surface_temperature_celcius': 66}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 93,
#               'datetime': '16-12-2021, 00:21:12',
#               'surface_temperature_celcius': 73}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 82,
#               'datetime': '16-12-2021, 00:21:11',
#               'surface_temperature_celcius': 55}}
# {'air_temperature_celcius': 18,
#  'hotspots': {'confidence': 82,
#               'datetime': '16-12-2021, 00:20:53',
#               'surface_temperature_celcius': 64}}
# {'air_temperature_celcius': 17,
#  'hotspots': {'confidence': 80,
#               'datetime': '25-12-2021, 04:29:08',
#               'surface_temperature_celcius': 54}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 82,
#               'datetime': '27-12-2021, 00:02:15',
#               'surface_temperature_celcius': 63}}
# {'air_temperature_celcius': 28,
#  'hotspots': {'confidence': 86,
#               'datetime': '27-12-2021, 00:02:14',
#               'surface_temperature_celcius': 67}}

# %% [markdown]
# #### e) Find the top 10 records with the highest surface temperature (°C).

# %%
cursor = db.embedded_climate_hotspot.aggregate([
    # since necessary detail (i.e., surface temperature) is in an associative array, hence I need to use unwind
    {"$unwind":"$hotspots"},
    # make sure the object id is not printed out
    {"$project":{"_id":0,"hotspots._id":0}},
    # sort the documents decending by its surface temperature
    {"$sort" : {"hotspots.surface_temperature_celcius":-1}},
    # only shows the top 10 documents
    {"$limit" : 10 }
])

"""
How to interpret my output:
My output shows all the details for the top 10 records with the highest surface temperature. 
The reason for this is because this is more convenient as it allows the client/user to retrieve all 
the details for these records. 
"""

for document in cursor: 
    document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
    document['hotspots']['date'] = document['hotspots']['date'].strftime('%d-%m-%Y') # make the date more readable
    # make the datetime more readable
    document['hotspots']['datetime'] = document['hotspots']['datetime'].strftime("%d-%m-%Y, %H:%M:%S")
    pprint(document)
# Out:
# {'GHI_w/m2': 122,
#  'air_temperature_celcius': 15,
#  'date': '18-04-2021',
#  'hotspots': {'confidence': 100,
#               'date': '18-04-2021',
#               'datetime': '18-04-2021, 04:52:00',
#               'latitude': -38.1665,
#               'longitude': 143.062,
#               'surface_temperature_celcius': 124},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 100,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:50',
#               'latitude': -36.343,
#               'longitude': 142.1986,
#               'surface_temperature_celcius': 123},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 121,
#  'air_temperature_celcius': 14,
#  'date': '01-05-2021',
#  'hotspots': {'confidence': 100,
#               'date': '01-05-2021',
#               'datetime': '01-05-2021, 04:14:20',
#               'latitude': -36.9318,
#               'longitude': 143.0907,
#               'surface_temperature_celcius': 122},
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 176,
#  'air_temperature_celcius': 21,
#  'date': '18-03-2021',
#  'hotspots': {'confidence': 100,
#               'date': '18-03-2021',
#               'datetime': '18-03-2021, 03:50:50',
#               'latitude': -37.016999999999996,
#               'longitude': 148.1297,
#               'surface_temperature_celcius': 121},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 100,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:40',
#               'latitude': -36.3521,
#               'longitude': 142.2008,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 132,
#  'air_temperature_celcius': 16,
#  'date': '13-04-2021',
#  'hotspots': {'confidence': 100,
#               'date': '13-04-2021',
#               'datetime': '13-04-2021, 04:28:10',
#               'latitude': -37.0745,
#               'longitude': 141.0692,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 81,
#  'air_temperature_celcius': 9,
#  'date': '13-05-2021',
#  'hotspots': {'confidence': 100,
#               'date': '13-05-2021',
#               'datetime': '13-05-2021, 04:40:20',
#               'latitude': -34.9938,
#               'longitude': 141.876,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 122,
#  'air_temperature_celcius': 15,
#  'date': '18-04-2021',
#  'hotspots': {'confidence': 100,
#               'date': '18-04-2021',
#               'datetime': '18-04-2021, 04:44:50',
#               'latitude': -37.8326,
#               'longitude': 143.4999,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 100,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:40:00',
#               'latitude': -36.1057,
#               'longitude': 141.7608,
#               'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 91,
#  'air_temperature_celcius': 10,
#  'date': '04-05-2021',
#  'hotspots': {'confidence': 100,
#               'date': '04-05-2021',
#               'datetime': '04-05-2021, 04:44:50',
#               'latitude': -36.4057,
#               'longitude': 140.9806,
#               'surface_temperature_celcius': 119},
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}

# %% [markdown]
# #### f) Find the number of fires each day. You are required to only display the total number of fires and the date in the output.

# %%
cursor = db.embedded_climate_hotspot.aggregate([
    {"$project":{"date":1,"number_of_fires": {"$size":"$hotspots"},"_id":0}},
    {"$sort" : {"date":1}} # not required to sort the date but just to make the output look neat
])

for document in cursor: 
    document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
    pprint(document)
# Out:
# {'date': '31-12-2020', 'number_of_fires': 0}
# {'date': '01-01-2021', 'number_of_fires': 0}
# {'date': '02-01-2021', 'number_of_fires': 0}
# {'date': '03-01-2021', 'number_of_fires': 0}
# {'date': '04-01-2021', 'number_of_fires': 0}
# {'date': '05-01-2021', 'number_of_fires': 0}
# {'date': '06-01-2021', 'number_of_fires': 0}
# {'date': '07-01-2021', 'number_of_fires': 0}
# {'date': '08-01-2021', 'number_of_fires': 0}
# {'date': '09-01-2021', 'number_of_fires': 0}
# {'date': '10-01-2021', 'number_of_fires': 0}
# {'date': '11-01-2021', 'number_of_fires': 0}
# {'date': '12-01-2021', 'number_of_fires': 0}
# {'date': '13-01-2021', 'number_of_fires': 0}
# {'date': '14-01-2021', 'number_of_fires': 0}
# {'date': '15-01-2021', 'number_of_fires': 0}
# {'date': '16-01-2021', 'number_of_fires': 0}
# {'date': '17-01-2021', 'number_of_fires': 0}
# {'date': '18-01-2021', 'number_of_fires': 0}
# {'date': '19-01-2021', 'number_of_fires': 0}
# {'date': '20-01-2021', 'number_of_fires': 0}
# {'date': '21-01-2021', 'number_of_fires': 0}
# {'date': '22-01-2021', 'number_of_fires': 0}
# {'date': '23-01-2021', 'number_of_fires': 0}
# {'date': '24-01-2021', 'number_of_fires': 0}
# {'date': '25-01-2021', 'number_of_fires': 0}
# {'date': '26-01-2021', 'number_of_fires': 0}
# {'date': '27-01-2021', 'number_of_fires': 0}
# {'date': '28-01-2021', 'number_of_fires': 0}
# {'date': '29-01-2021', 'number_of_fires': 0}
# {'date': '30-01-2021', 'number_of_fires': 0}
# {'date': '31-01-2021', 'number_of_fires': 0}
# {'date': '01-02-2021', 'number_of_fires': 0}
# {'date': '02-02-2021', 'number_of_fires': 0}
# {'date': '03-02-2021', 'number_of_fires': 0}
# {'date': '04-02-2021', 'number_of_fires': 0}
# {'date': '05-02-2021', 'number_of_fires': 0}
# {'date': '06-02-2021', 'number_of_fires': 0}
# {'date': '07-02-2021', 'number_of_fires': 0}
# {'date': '08-02-2021', 'number_of_fires': 0}
# {'date': '09-02-2021', 'number_of_fires': 0}
# {'date': '10-02-2021', 'number_of_fires': 0}
# {'date': '11-02-2021', 'number_of_fires': 0}
# {'date': '12-02-2021', 'number_of_fires': 0}
# {'date': '13-02-2021', 'number_of_fires': 0}
# {'date': '14-02-2021', 'number_of_fires': 0}
# {'date': '15-02-2021', 'number_of_fires': 0}
# {'date': '16-02-2021', 'number_of_fires': 0}
# {'date': '17-02-2021', 'number_of_fires': 0}
# {'date': '18-02-2021', 'number_of_fires': 0}
# {'date': '19-02-2021', 'number_of_fires': 0}
# {'date': '20-02-2021', 'number_of_fires': 0}
# {'date': '21-02-2021', 'number_of_fires': 0}
# {'date': '22-02-2021', 'number_of_fires': 0}
# {'date': '23-02-2021', 'number_of_fires': 0}
# {'date': '24-02-2021', 'number_of_fires': 0}
# {'date': '25-02-2021', 'number_of_fires': 0}
# {'date': '26-02-2021', 'number_of_fires': 0}
# {'date': '27-02-2021', 'number_of_fires': 0}
# {'date': '28-02-2021', 'number_of_fires': 0}
# {'date': '01-03-2021', 'number_of_fires': 0}
# {'date': '02-03-2021', 'number_of_fires': 0}
# {'date': '03-03-2021', 'number_of_fires': 0}
# {'date': '04-03-2021', 'number_of_fires': 0}
# {'date': '05-03-2021', 'number_of_fires': 0}
# {'date': '06-03-2021', 'number_of_fires': 2}
# {'date': '07-03-2021', 'number_of_fires': 1}
# {'date': '08-03-2021', 'number_of_fires': 2}
# {'date': '09-03-2021', 'number_of_fires': 3}
# {'date': '10-03-2021', 'number_of_fires': 8}
# {'date': '11-03-2021', 'number_of_fires': 0}
# {'date': '12-03-2021', 'number_of_fires': 5}
# {'date': '13-03-2021', 'number_of_fires': 2}
# {'date': '14-03-2021', 'number_of_fires': 10}
# {'date': '15-03-2021', 'number_of_fires': 7}
# {'date': '16-03-2021', 'number_of_fires': 0}
# {'date': '17-03-2021', 'number_of_fires': 6}
# {'date': '18-03-2021', 'number_of_fires': 3}
# {'date': '19-03-2021', 'number_of_fires': 21}
# {'date': '20-03-2021', 'number_of_fires': 0}
# {'date': '21-03-2021', 'number_of_fires': 0}
# {'date': '22-03-2021', 'number_of_fires': 0}
# {'date': '23-03-2021', 'number_of_fires': 0}
# {'date': '24-03-2021', 'number_of_fires': 2}
# {'date': '25-03-2021', 'number_of_fires': 13}
# {'date': '26-03-2021', 'number_of_fires': 17}
# {'date': '27-03-2021', 'number_of_fires': 0}
# {'date': '28-03-2021', 'number_of_fires': 54}
# {'date': '29-03-2021', 'number_of_fires': 1}
# {'date': '30-03-2021', 'number_of_fires': 0}
# {'date': '31-03-2021', 'number_of_fires': 22}
# {'date': '01-04-2021', 'number_of_fires': 7}
# {'date': '02-04-2021', 'number_of_fires': 5}
# {'date': '03-04-2021', 'number_of_fires': 72}
# {'date': '04-04-2021', 'number_of_fires': 89}
# {'date': '05-04-2021', 'number_of_fires': 49}
# {'date': '06-04-2021', 'number_of_fires': 118}
# {'date': '07-04-2021', 'number_of_fires': 39}
# {'date': '08-04-2021', 'number_of_fires': 20}
# {'date': '09-04-2021', 'number_of_fires': 0}
# {'date': '10-04-2021', 'number_of_fires': 0}
# {'date': '11-04-2021', 'number_of_fires': 24}
# {'date': '12-04-2021', 'number_of_fires': 69}
# {'date': '13-04-2021', 'number_of_fires': 357}
# {'date': '14-04-2021', 'number_of_fires': 18}
# {'date': '15-04-2021', 'number_of_fires': 69}
# {'date': '16-04-2021', 'number_of_fires': 18}
# {'date': '17-04-2021', 'number_of_fires': 38}
# {'date': '18-04-2021', 'number_of_fires': 325}
# {'date': '19-04-2021', 'number_of_fires': 50}
# {'date': '20-04-2021', 'number_of_fires': 31}
# {'date': '21-04-2021', 'number_of_fires': 0}
# {'date': '22-04-2021', 'number_of_fires': 2}
# {'date': '23-04-2021', 'number_of_fires': 19}
# {'date': '24-04-2021', 'number_of_fires': 8}
# {'date': '25-04-2021', 'number_of_fires': 3}
# {'date': '26-04-2021', 'number_of_fires': 1}
# {'date': '27-04-2021', 'number_of_fires': 0}
# {'date': '28-04-2021', 'number_of_fires': 0}
# {'date': '29-04-2021', 'number_of_fires': 3}
# {'date': '30-04-2021', 'number_of_fires': 0}
# {'date': '01-05-2021', 'number_of_fires': 20}
# {'date': '02-05-2021', 'number_of_fires': 10}
# {'date': '03-05-2021', 'number_of_fires': 64}
# {'date': '04-05-2021', 'number_of_fires': 135}
# {'date': '05-05-2021', 'number_of_fires': 31}
# {'date': '06-05-2021', 'number_of_fires': 17}
# {'date': '07-05-2021', 'number_of_fires': 3}
# {'date': '08-05-2021', 'number_of_fires': 24}
# {'date': '09-05-2021', 'number_of_fires': 13}
# {'date': '10-05-2021', 'number_of_fires': 114}
# {'date': '11-05-2021', 'number_of_fires': 19}
# {'date': '12-05-2021', 'number_of_fires': 10}
# {'date': '13-05-2021', 'number_of_fires': 54}
# {'date': '14-05-2021', 'number_of_fires': 1}
# {'date': '15-05-2021', 'number_of_fires': 102}
# {'date': '16-05-2021', 'number_of_fires': 3}
# {'date': '17-05-2021', 'number_of_fires': 1}
# {'date': '18-05-2021', 'number_of_fires': 7}
# {'date': '19-05-2021', 'number_of_fires': 0}
# {'date': '20-05-2021', 'number_of_fires': 0}
# {'date': '21-05-2021', 'number_of_fires': 0}
# {'date': '22-05-2021', 'number_of_fires': 33}
# {'date': '23-05-2021', 'number_of_fires': 5}
# {'date': '24-05-2021', 'number_of_fires': 3}
# {'date': '25-05-2021', 'number_of_fires': 0}
# {'date': '26-05-2021', 'number_of_fires': 4}
# {'date': '27-05-2021', 'number_of_fires': 0}
# {'date': '28-05-2021', 'number_of_fires': 0}
# {'date': '29-05-2021', 'number_of_fires': 0}
# {'date': '30-05-2021', 'number_of_fires': 0}
# {'date': '31-05-2021', 'number_of_fires': 0}
# {'date': '01-06-2021', 'number_of_fires': 2}
# {'date': '02-06-2021', 'number_of_fires': 11}
# {'date': '03-06-2021', 'number_of_fires': 2}
# {'date': '04-06-2021', 'number_of_fires': 9}
# {'date': '05-06-2021', 'number_of_fires': 0}
# {'date': '06-06-2021', 'number_of_fires': 0}
# {'date': '07-06-2021', 'number_of_fires': 14}
# {'date': '08-06-2021', 'number_of_fires': 0}
# {'date': '09-06-2021', 'number_of_fires': 3}
# {'date': '10-06-2021', 'number_of_fires': 0}
# {'date': '11-06-2021', 'number_of_fires': 2}
# {'date': '12-06-2021', 'number_of_fires': 0}
# {'date': '13-06-2021', 'number_of_fires': 1}
# {'date': '14-06-2021', 'number_of_fires': 4}
# {'date': '15-06-2021', 'number_of_fires': 0}
# {'date': '16-06-2021', 'number_of_fires': 2}
# {'date': '17-06-2021', 'number_of_fires': 0}
# {'date': '18-06-2021', 'number_of_fires': 2}
# {'date': '19-06-2021', 'number_of_fires': 0}
# {'date': '20-06-2021', 'number_of_fires': 6}
# {'date': '21-06-2021', 'number_of_fires': 0}
# {'date': '22-06-2021', 'number_of_fires': 1}
# {'date': '23-06-2021', 'number_of_fires': 0}
# {'date': '24-06-2021', 'number_of_fires': 0}
# {'date': '25-06-2021', 'number_of_fires': 0}
# {'date': '26-06-2021', 'number_of_fires': 0}
# {'date': '27-06-2021', 'number_of_fires': 0}
# {'date': '28-06-2021', 'number_of_fires': 0}
# {'date': '29-06-2021', 'number_of_fires': 0}
# {'date': '30-06-2021', 'number_of_fires': 6}
# {'date': '01-07-2021', 'number_of_fires': 4}
# {'date': '02-07-2021', 'number_of_fires': 8}
# {'date': '03-07-2021', 'number_of_fires': 0}
# {'date': '04-07-2021', 'number_of_fires': 1}
# {'date': '05-07-2021', 'number_of_fires': 1}
# {'date': '06-07-2021', 'number_of_fires': 3}
# {'date': '07-07-2021', 'number_of_fires': 0}
# {'date': '08-07-2021', 'number_of_fires': 0}
# {'date': '09-07-2021', 'number_of_fires': 0}
# {'date': '10-07-2021', 'number_of_fires': 0}
# {'date': '11-07-2021', 'number_of_fires': 0}
# {'date': '12-07-2021', 'number_of_fires': 0}
# {'date': '13-07-2021', 'number_of_fires': 0}
# {'date': '14-07-2021', 'number_of_fires': 2}
# {'date': '15-07-2021', 'number_of_fires': 0}
# {'date': '16-07-2021', 'number_of_fires': 0}
# {'date': '17-07-2021', 'number_of_fires': 0}
# {'date': '18-07-2021', 'number_of_fires': 0}
# {'date': '19-07-2021', 'number_of_fires': 0}
# {'date': '20-07-2021', 'number_of_fires': 0}
# {'date': '21-07-2021', 'number_of_fires': 0}
# {'date': '22-07-2021', 'number_of_fires': 0}
# {'date': '23-07-2021', 'number_of_fires': 0}
# {'date': '24-07-2021', 'number_of_fires': 0}
# {'date': '25-07-2021', 'number_of_fires': 0}
# {'date': '26-07-2021', 'number_of_fires': 0}
# {'date': '27-07-2021', 'number_of_fires': 0}
# {'date': '28-07-2021', 'number_of_fires': 0}
# {'date': '29-07-2021', 'number_of_fires': 2}
# {'date': '30-07-2021', 'number_of_fires': 0}
# {'date': '31-07-2021', 'number_of_fires': 2}
# {'date': '01-08-2021', 'number_of_fires': 2}
# {'date': '02-08-2021', 'number_of_fires': 2}
# {'date': '03-08-2021', 'number_of_fires': 0}
# {'date': '04-08-2021', 'number_of_fires': 0}
# {'date': '05-08-2021', 'number_of_fires': 1}
# {'date': '06-08-2021', 'number_of_fires': 0}
# {'date': '07-08-2021', 'number_of_fires': 0}
# {'date': '08-08-2021', 'number_of_fires': 0}
# {'date': '09-08-2021', 'number_of_fires': 0}
# {'date': '10-08-2021', 'number_of_fires': 1}
# {'date': '11-08-2021', 'number_of_fires': 0}
# {'date': '12-08-2021', 'number_of_fires': 0}
# {'date': '13-08-2021', 'number_of_fires': 9}
# {'date': '14-08-2021', 'number_of_fires': 5}
# {'date': '15-08-2021', 'number_of_fires': 0}
# {'date': '16-08-2021', 'number_of_fires': 0}
# {'date': '17-08-2021', 'number_of_fires': 0}
# {'date': '18-08-2021', 'number_of_fires': 0}
# {'date': '19-08-2021', 'number_of_fires': 0}
# {'date': '20-08-2021', 'number_of_fires': 0}
# {'date': '21-08-2021', 'number_of_fires': 0}
# {'date': '22-08-2021', 'number_of_fires': 0}
# {'date': '23-08-2021', 'number_of_fires': 0}
# {'date': '24-08-2021', 'number_of_fires': 0}
# {'date': '25-08-2021', 'number_of_fires': 0}
# {'date': '26-08-2021', 'number_of_fires': 0}
# {'date': '27-08-2021', 'number_of_fires': 0}
# {'date': '28-08-2021', 'number_of_fires': 0}
# {'date': '29-08-2021', 'number_of_fires': 0}
# {'date': '30-08-2021', 'number_of_fires': 0}
# {'date': '31-08-2021', 'number_of_fires': 0}
# {'date': '01-09-2021', 'number_of_fires': 0}
# {'date': '02-09-2021', 'number_of_fires': 0}
# {'date': '03-09-2021', 'number_of_fires': 0}
# {'date': '04-09-2021', 'number_of_fires': 0}
# {'date': '05-09-2021', 'number_of_fires': 0}
# {'date': '06-09-2021', 'number_of_fires': 0}
# {'date': '07-09-2021', 'number_of_fires': 0}
# {'date': '08-09-2021', 'number_of_fires': 0}
# {'date': '09-09-2021', 'number_of_fires': 0}
# {'date': '10-09-2021', 'number_of_fires': 4}
# {'date': '11-09-2021', 'number_of_fires': 0}
# {'date': '12-09-2021', 'number_of_fires': 0}
# {'date': '13-09-2021', 'number_of_fires': 0}
# {'date': '14-09-2021', 'number_of_fires': 0}
# {'date': '15-09-2021', 'number_of_fires': 0}
# {'date': '16-09-2021', 'number_of_fires': 0}
# {'date': '17-09-2021', 'number_of_fires': 0}
# {'date': '18-09-2021', 'number_of_fires': 0}
# {'date': '19-09-2021', 'number_of_fires': 0}
# {'date': '20-09-2021', 'number_of_fires': 5}
# {'date': '21-09-2021', 'number_of_fires': 2}
# {'date': '22-09-2021', 'number_of_fires': 1}
# {'date': '23-09-2021', 'number_of_fires': 23}
# {'date': '24-09-2021', 'number_of_fires': 28}
# {'date': '25-09-2021', 'number_of_fires': 0}
# {'date': '26-09-2021', 'number_of_fires': 1}
# {'date': '27-09-2021', 'number_of_fires': 7}
# {'date': '28-09-2021', 'number_of_fires': 0}
# {'date': '29-09-2021', 'number_of_fires': 2}
# {'date': '30-09-2021', 'number_of_fires': 0}
# {'date': '01-10-2021', 'number_of_fires': 8}
# {'date': '02-10-2021', 'number_of_fires': 7}
# {'date': '03-10-2021', 'number_of_fires': 18}
# {'date': '04-10-2021', 'number_of_fires': 5}
# {'date': '05-10-2021', 'number_of_fires': 0}
# {'date': '06-10-2021', 'number_of_fires': 2}
# {'date': '07-10-2021', 'number_of_fires': 1}
# {'date': '08-10-2021', 'number_of_fires': 1}
# {'date': '09-10-2021', 'number_of_fires': 1}
# {'date': '10-10-2021', 'number_of_fires': 3}
# {'date': '11-10-2021', 'number_of_fires': 0}
# {'date': '12-10-2021', 'number_of_fires': 0}
# {'date': '13-10-2021', 'number_of_fires': 0}
# {'date': '14-10-2021', 'number_of_fires': 0}
# {'date': '15-10-2021', 'number_of_fires': 3}
# {'date': '16-10-2021', 'number_of_fires': 1}
# {'date': '17-10-2021', 'number_of_fires': 5}
# {'date': '18-10-2021', 'number_of_fires': 6}
# {'date': '19-10-2021', 'number_of_fires': 0}
# {'date': '20-10-2021', 'number_of_fires': 3}
# {'date': '21-10-2021', 'number_of_fires': 4}
# {'date': '22-10-2021', 'number_of_fires': 0}
# {'date': '23-10-2021', 'number_of_fires': 1}
# {'date': '24-10-2021', 'number_of_fires': 0}
# {'date': '25-10-2021', 'number_of_fires': 0}
# {'date': '26-10-2021', 'number_of_fires': 5}
# {'date': '27-10-2021', 'number_of_fires': 5}
# {'date': '28-10-2021', 'number_of_fires': 1}
# {'date': '29-10-2021', 'number_of_fires': 0}
# {'date': '30-10-2021', 'number_of_fires': 0}
# {'date': '31-10-2021', 'number_of_fires': 0}
# {'date': '01-11-2021', 'number_of_fires': 0}
# {'date': '02-11-2021', 'number_of_fires': 0}
# {'date': '03-11-2021', 'number_of_fires': 0}
# {'date': '04-11-2021', 'number_of_fires': 0}
# {'date': '05-11-2021', 'number_of_fires': 4}
# {'date': '06-11-2021', 'number_of_fires': 0}
# {'date': '07-11-2021', 'number_of_fires': 0}
# {'date': '08-11-2021', 'number_of_fires': 2}
# {'date': '09-11-2021', 'number_of_fires': 10}
# {'date': '10-11-2021', 'number_of_fires': 0}
# {'date': '11-11-2021', 'number_of_fires': 4}
# {'date': '12-11-2021', 'number_of_fires': 5}
# {'date': '13-11-2021', 'number_of_fires': 5}
# {'date': '14-11-2021', 'number_of_fires': 3}
# {'date': '15-11-2021', 'number_of_fires': 0}
# {'date': '16-11-2021', 'number_of_fires': 0}
# {'date': '17-11-2021', 'number_of_fires': 0}
# {'date': '18-11-2021', 'number_of_fires': 0}
# {'date': '19-11-2021', 'number_of_fires': 0}
# {'date': '20-11-2021', 'number_of_fires': 0}
# {'date': '21-11-2021', 'number_of_fires': 1}
# {'date': '22-11-2021', 'number_of_fires': 2}
# {'date': '23-11-2021', 'number_of_fires': 5}
# {'date': '24-11-2021', 'number_of_fires': 0}
# {'date': '25-11-2021', 'number_of_fires': 0}
# {'date': '26-11-2021', 'number_of_fires': 0}
# {'date': '27-11-2021', 'number_of_fires': 0}
# {'date': '28-11-2021', 'number_of_fires': 1}
# {'date': '29-11-2021', 'number_of_fires': 8}
# {'date': '30-11-2021', 'number_of_fires': 31}
# {'date': '01-12-2021', 'number_of_fires': 0}
# {'date': '02-12-2021', 'number_of_fires': 0}
# {'date': '03-12-2021', 'number_of_fires': 0}
# {'date': '04-12-2021', 'number_of_fires': 0}
# {'date': '05-12-2021', 'number_of_fires': 0}
# {'date': '06-12-2021', 'number_of_fires': 0}
# {'date': '07-12-2021', 'number_of_fires': 0}
# {'date': '08-12-2021', 'number_of_fires': 5}
# {'date': '09-12-2021', 'number_of_fires': 4}
# {'date': '10-12-2021', 'number_of_fires': 2}
# {'date': '11-12-2021', 'number_of_fires': 0}
# {'date': '12-12-2021', 'number_of_fires': 1}
# {'date': '13-12-2021', 'number_of_fires': 1}
# {'date': '14-12-2021', 'number_of_fires': 1}
# {'date': '15-12-2021', 'number_of_fires': 4}
# {'date': '16-12-2021', 'number_of_fires': 15}
# {'date': '17-12-2021', 'number_of_fires': 0}
# {'date': '18-12-2021', 'number_of_fires': 0}
# {'date': '19-12-2021', 'number_of_fires': 0}
# {'date': '20-12-2021', 'number_of_fires': 0}
# {'date': '21-12-2021', 'number_of_fires': 1}
# {'date': '22-12-2021', 'number_of_fires': 0}
# {'date': '23-12-2021', 'number_of_fires': 0}
# {'date': '24-12-2021', 'number_of_fires': 1}
# {'date': '25-12-2021', 'number_of_fires': 1}
# {'date': '26-12-2021', 'number_of_fires': 0}
# {'date': '27-12-2021', 'number_of_fires': 4}
# {'date': '28-12-2021', 'number_of_fires': 0}
# {'date': '29-12-2021', 'number_of_fires': 0}
# {'date': '30-12-2021', 'number_of_fires': 0}
# {'date': '31-12-2021', 'number_of_fires': 0}

# %% [markdown]
# #### g) Find the records of fires where the confidence is below 70

# %%
cursor = db.embedded_climate_hotspot.aggregate([
    # since necessary detail is in an associative array, hence I need to use unwind
    {"$unwind":"$hotspots"},
    # only include the documents when its confidence is below 70
    {"$match": {"hotspots.confidence":{"$lt":70}}},
    # make sure object id is not included
    {"$project":{"_id":0,"hotspots._id":0}}
])

"""
How to interpret my output:
Similar to question e, my output shows all the details for all the documents when its confidence is below 70. 
The reason for this is because this is more convenient as it allows the client/user to retrieve all 
the details for these records. 
"""

for document in cursor: 
    document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
    document['hotspots']['date'] = document['hotspots']['date'].strftime('%d-%m-%Y') # make the date more readable
    # make the datetime more readable
    document['hotspots']['datetime'] = document['hotspots']['datetime'].strftime("%d-%m-%Y, %H:%M:%S")
    pprint(document)
# Out:
# {'GHI_w/m2': 177,
#  'air_temperature_celcius': 21,
#  'date': '08-03-2021',
#  'hotspots': {'confidence': 68,
#               'date': '08-03-2021',
#               'datetime': '08-03-2021, 04:51:00',
#               'latitude': -37.7885,
#               'longitude': 141.9352,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.7,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 192,
#  'air_temperature_celcius': 23,
#  'date': '09-03-2021',
#  'hotspots': {'confidence': 54,
#               'date': '09-03-2021',
#               'datetime': '09-03-2021, 03:57:00',
#               'latitude': -37.7171,
#               'longitude': 147.5866,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 19,
#  'date': '10-03-2021',
#  'hotspots': {'confidence': 55,
#               'date': '10-03-2021',
#               'datetime': '10-03-2021, 04:43:00',
#               'latitude': -36.2544,
#               'longitude': 148.0353,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 19,
#  'date': '10-03-2021',
#  'hotspots': {'confidence': 54,
#               'date': '10-03-2021',
#               'datetime': '10-03-2021, 04:42:30',
#               'latitude': -37.2197,
#               'longitude': 147.9621,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 154,
#  'air_temperature_celcius': 20,
#  'date': '13-03-2021',
#  'hotspots': {'confidence': 56,
#               'date': '13-03-2021',
#               'datetime': '13-03-2021, 23:58:50',
#               'latitude': -37.0286,
#               'longitude': 148.155,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 154,
#  'air_temperature_celcius': 20,
#  'date': '13-03-2021',
#  'hotspots': {'confidence': 52,
#               'date': '13-03-2021',
#               'datetime': '13-03-2021, 12:57:00',
#               'latitude': -37.0316,
#               'longitude': 148.1519,
#               'surface_temperature_celcius': 35},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 223,
#  'air_temperature_celcius': 28,
#  'date': '15-03-2021',
#  'hotspots': {'confidence': 52,
#               'date': '15-03-2021',
#               'datetime': '15-03-2021, 00:42:50',
#               'latitude': -37.4075,
#               'longitude': 147.0233,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 223,
#  'air_temperature_celcius': 28,
#  'date': '15-03-2021',
#  'hotspots': {'confidence': 66,
#               'date': '15-03-2021',
#               'datetime': '15-03-2021, 00:42:50',
#               'latitude': -37.0228,
#               'longitude': 148.1281,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 223,
#  'air_temperature_celcius': 28,
#  'date': '15-03-2021',
#  'hotspots': {'confidence': 51,
#               'date': '15-03-2021',
#               'datetime': '15-03-2021, 00:42:40',
#               'latitude': -37.001999999999995,
#               'longitude': 148.2055,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 176,
#  'air_temperature_celcius': 21,
#  'date': '18-03-2021',
#  'hotspots': {'confidence': 64,
#               'date': '18-03-2021',
#               'datetime': '18-03-2021, 13:16:50',
#               'latitude': -37.4313,
#               'longitude': 147.0343,
#               'surface_temperature_celcius': 37},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 58,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:39:20',
#               'latitude': -37.9164,
#               'longitude': 143.4866,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 63,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:39:20',
#               'latitude': -37.9257,
#               'longitude': 143.4891,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 64,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:36:00',
#               'latitude': -37.3982,
#               'longitude': 147.0001,
#               'surface_temperature_celcius': 58},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 59,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:35:00',
#               'latitude': -37.4023,
#               'longitude': 147.0394,
#               'surface_temperature_celcius': 56},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 60,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:33:50',
#               'latitude': -37.4336,
#               'longitude': 147.0534,
#               'surface_temperature_celcius': 51},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 61,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:33:30',
#               'latitude': -37.4003,
#               'longitude': 147.0448,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 53,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:33:30',
#               'latitude': -37.9184,
#               'longitude': 143.4745,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 61,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:33:10',
#               'latitude': -37.3911,
#               'longitude': 147.037,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 66,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 04:32:50',
#               'latitude': -37.9277,
#               'longitude': 143.477,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  'air_temperature_celcius': 24,
#  'date': '19-03-2021',
#  'hotspots': {'confidence': 60,
#               'date': '19-03-2021',
#               'datetime': '19-03-2021, 00:12:50',
#               'latitude': -37.3942,
#               'longitude': 147.0455,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 159,
#  'air_temperature_celcius': 20,
#  'date': '24-03-2021',
#  'hotspots': {'confidence': 65,
#               'date': '24-03-2021',
#               'datetime': '24-03-2021, 04:58:00',
#               'latitude': -37.1603,
#               'longitude': 142.8088,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 159,
#  'air_temperature_celcius': 20,
#  'date': '24-03-2021',
#  'hotspots': {'confidence': 55,
#               'date': '24-03-2021',
#               'datetime': '24-03-2021, 04:56:10',
#               'latitude': -37.1684,
#               'longitude': 142.8183,
#               'surface_temperature_celcius': 48},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 178,
#  'air_temperature_celcius': 23,
#  'date': '25-03-2021',
#  'hotspots': {'confidence': 62,
#               'date': '25-03-2021',
#               'datetime': '25-03-2021, 04:03:10',
#               'latitude': -37.8992,
#               'longitude': 143.4534,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 178,
#  'air_temperature_celcius': 23,
#  'date': '25-03-2021',
#  'hotspots': {'confidence': 57,
#               'date': '25-03-2021',
#               'datetime': '25-03-2021, 03:56:40',
#               'latitude': -37.9022,
#               'longitude': 143.4607,
#               'surface_temperature_celcius': 57},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 180,
#  'air_temperature_celcius': 23,
#  'date': '26-03-2021',
#  'hotspots': {'confidence': 68,
#               'date': '26-03-2021',
#               'datetime': '26-03-2021, 04:41:10',
#               'latitude': -38.1131,
#               'longitude': 143.7173,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 26.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 180,
#  'air_temperature_celcius': 23,
#  'date': '26-03-2021',
#  'hotspots': {'confidence': 60,
#               'date': '26-03-2021',
#               'datetime': '26-03-2021, 04:39:10',
#               'latitude': -37.8469,
#               'longitude': 143.5343,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 26.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 180,
#  'air_temperature_celcius': 23,
#  'date': '26-03-2021',
#  'hotspots': {'confidence': 67,
#               'date': '26-03-2021',
#               'datetime': '26-03-2021, 04:39:10',
#               'latitude': -37.1956,
#               'longitude': 141.0252,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 26.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 154,
#  'air_temperature_celcius': 18,
#  'date': '28-03-2021',
#  'hotspots': {'confidence': 53,
#               'date': '28-03-2021',
#               'datetime': '28-03-2021, 04:29:30',
#               'latitude': -37.6195,
#               'longitude': 143.4212,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 154,
#  'air_temperature_celcius': 18,
#  'date': '28-03-2021',
#  'hotspots': {'confidence': 63,
#               'date': '28-03-2021',
#               'datetime': '28-03-2021, 04:26:50',
#               'latitude': -37.6376,
#               'longitude': 143.4255,
#               'surface_temperature_celcius': 48},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 154,
#  'air_temperature_celcius': 18,
#  'date': '28-03-2021',
#  'hotspots': {'confidence': 69,
#               'date': '28-03-2021',
#               'datetime': '28-03-2021, 04:26:50',
#               'latitude': -36.4422,
#               'longitude': 141.4172,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 154,
#  'air_temperature_celcius': 18,
#  'date': '28-03-2021',
#  'hotspots': {'confidence': 55,
#               'date': '28-03-2021',
#               'datetime': '28-03-2021, 04:26:50',
#               'latitude': -34.342,
#               'longitude': 141.6548,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 146,
#  'air_temperature_celcius': 17,
#  'date': '29-03-2021',
#  'hotspots': {'confidence': 69,
#               'date': '29-03-2021',
#               'datetime': '29-03-2021, 00:48:40',
#               'latitude': -34.2648,
#               'longitude': 141.6325,
#               'surface_temperature_celcius': 51},
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '31-03-2021',
#  'hotspots': {'confidence': 68,
#               'date': '31-03-2021',
#               'datetime': '31-03-2021, 04:57:50',
#               'latitude': -36.1649,
#               'longitude': 145.9352,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '31-03-2021',
#  'hotspots': {'confidence': 68,
#               'date': '31-03-2021',
#               'datetime': '31-03-2021, 04:57:40',
#               'latitude': -36.0436,
#               'longitude': 145.7964,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '31-03-2021',
#  'hotspots': {'confidence': 52,
#               'date': '31-03-2021',
#               'datetime': '31-03-2021, 04:57:10',
#               'latitude': -36.7134,
#               'longitude': 145.2151,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '31-03-2021',
#  'hotspots': {'confidence': 61,
#               'date': '31-03-2021',
#               'datetime': '31-03-2021, 04:57:10',
#               'latitude': -36.7028,
#               'longitude': 145.2519,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '31-03-2021',
#  'hotspots': {'confidence': 51,
#               'date': '31-03-2021',
#               'datetime': '31-03-2021, 04:57:10',
#               'latitude': -37.561,
#               'longitude': 143.24200000000002,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '31-03-2021',
#  'hotspots': {'confidence': 56,
#               'date': '31-03-2021',
#               'datetime': '31-03-2021, 04:57:10',
#               'latitude': -37.982,
#               'longitude': 143.6422,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '31-03-2021',
#  'hotspots': {'confidence': 51,
#               'date': '31-03-2021',
#               'datetime': '31-03-2021, 00:36:30',
#               'latitude': -34.2568,
#               'longitude': 141.64,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '01-04-2021',
#  'hotspots': {'confidence': 58,
#               'date': '01-04-2021',
#               'datetime': '01-04-2021, 04:02:40',
#               'latitude': -36.2044,
#               'longitude': 145.7706,
#               'surface_temperature_celcius': 51},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '01-04-2021',
#  'hotspots': {'confidence': 57,
#               'date': '01-04-2021',
#               'datetime': '01-04-2021, 04:02:40',
#               'latitude': -36.5245,
#               'longitude': 143.1556,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 124,
#  'air_temperature_celcius': 14,
#  'date': '01-04-2021',
#  'hotspots': {'confidence': 50,
#               'date': '01-04-2021',
#               'datetime': '01-04-2021, 04:02:40',
#               'latitude': -36.1002,
#               'longitude': 147.6494,
#               'surface_temperature_celcius': 39},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 109,
#  'air_temperature_celcius': 12,
#  'date': '02-04-2021',
#  'hotspots': {'confidence': 60,
#               'date': '02-04-2021',
#               'datetime': '02-04-2021, 04:53:30',
#               'latitude': -36.3872,
#               'longitude': 145.3858,
#               'surface_temperature_celcius': 40},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 109,
#  'air_temperature_celcius': 12,
#  'date': '02-04-2021',
#  'hotspots': {'confidence': 63,
#               'date': '02-04-2021',
#               'datetime': '02-04-2021, 04:45:10',
#               'latitude': -36.494,
#               'longitude': 145.4522,
#               'surface_temperature_celcius': 41},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 109,
#  'air_temperature_celcius': 12,
#  'date': '02-04-2021',
#  'hotspots': {'confidence': 60,
#               'date': '02-04-2021',
#               'datetime': '02-04-2021, 00:24:50',
#               'latitude': -37.324,
#               'longitude': 146.1647,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 69,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:53:50',
#               'latitude': -37.8668,
#               'longitude': 143.0472,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 68,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:53:40',
#               'latitude': -37.7602,
#               'longitude': 143.382,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:53:30',
#               'latitude': -37.7885,
#               'longitude': 142.9509,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:52:10',
#               'latitude': -37.8717,
#               'longitude': 143.2566,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 67,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:51:10',
#               'latitude': -37.8011,
#               'longitude': 144.7343,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 67,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:50',
#               'latitude': -37.0241,
#               'longitude': 141.5163,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:50',
#               'latitude': -37.2912,
#               'longitude': 143.543,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 52,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:50',
#               'latitude': -37.313,
#               'longitude': 146.1561,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 56,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:50',
#               'latitude': -38.0226,
#               'longitude': 143.6739,
#               'surface_temperature_celcius': 39},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 56,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:40',
#               'latitude': -37.8089,
#               'longitude': 145.9555,
#               'surface_temperature_celcius': 41},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 62,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:40',
#               'latitude': -37.9009,
#               'longitude': 143.6217,
#               'surface_temperature_celcius': 45},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 69,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:40',
#               'latitude': -37.7836,
#               'longitude': 142.9437,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 52,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:40',
#               'latitude': -37.0484,
#               'longitude': 141.6245,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 68,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 03:50:40',
#               'latitude': -36.911,
#               'longitude': 142.1445,
#               'surface_temperature_celcius': 47},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 67,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 01:11:00',
#               'latitude': -34.2536,
#               'longitude': 141.6199,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '03-04-2021',
#  'hotspots': {'confidence': 57,
#               'date': '03-04-2021',
#               'datetime': '03-04-2021, 01:07:00',
#               'latitude': -34.2614,
#               'longitude': 141.6412,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 63,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 15:30:40',
#               'latitude': -36.0933,
#               'longitude': 141.7154,
#               'surface_temperature_celcius': 35},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 64,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:39:50',
#               'latitude': -36.6281,
#               'longitude': 142.4349,
#               'surface_temperature_celcius': 68},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 61,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:39:40',
#               'latitude': -36.937,
#               'longitude': 142.1176,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 50,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:38:10',
#               'latitude': -36.6951,
#               'longitude': 145.424,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 67,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:36:30',
#               'latitude': -37.6714,
#               'longitude': 144.2154,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 63,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:36:30',
#               'latitude': -38.0494,
#               'longitude': 143.9141,
#               'surface_temperature_celcius': 58},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 54,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:34:20',
#               'latitude': -38.4879,
#               'longitude': 143.9971,
#               'surface_temperature_celcius': 40},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 63,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:33:30',
#               'latitude': -37.1744,
#               'longitude': 143.9256,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 69,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:33:30',
#               'latitude': -36.4918,
#               'longitude': 142.2465,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:33:10',
#               'latitude': -36.6299,
#               'longitude': 142.4234,
#               'surface_temperature_celcius': 71},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 53,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:33:10',
#               'latitude': -36.1439,
#               'longitude': 145.832,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 54,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:50',
#               'latitude': -36.7009,
#               'longitude': 141.541,
#               'surface_temperature_celcius': 49},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 55,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:40',
#               'latitude': -36.4611,
#               'longitude': 143.14600000000002,
#               'surface_temperature_celcius': 48},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 53,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:40',
#               'latitude': -36.3539,
#               'longitude': 142.1894,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:40',
#               'latitude': -37.0081,
#               'longitude': 141.7654,
#               'surface_temperature_celcius': 62},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 64,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:40',
#               'latitude': -36.2889,
#               'longitude': 141.7692,
#               'surface_temperature_celcius': 51},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 67,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:40',
#               'latitude': -36.6228,
#               'longitude': 142.428,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 16,
#  'date': '04-04-2021',
#  'hotspots': {'confidence': 60,
#               'date': '04-04-2021',
#               'datetime': '04-04-2021, 04:32:40',
#               'latitude': -38.1177,
#               'longitude': 143.6409,
#               'surface_temperature_celcius': 40},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 61,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 13:10:10',
#               'latitude': -38.3499,
#               'longitude': 147.033,
#               'surface_temperature_celcius': 35},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 13:02:40',
#               'latitude': -37.6435,
#               'longitude': 146.1417,
#               'surface_temperature_celcius': 36},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 05:15:40',
#               'latitude': -37.7522,
#               'longitude': 142.3183,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 05:15:30',
#               'latitude': -36.9396,
#               'longitude': 141.9303,
#               'surface_temperature_celcius': 45},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 65,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:45:10',
#               'latitude': -37.78,
#               'longitude': 141.8091,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 68,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:44:40',
#               'latitude': -37.7767,
#               'longitude': 141.8127,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 65,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:44:30',
#               'latitude': -38.1756,
#               'longitude': 143.9829,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 50,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:40:30',
#               'latitude': -38.3553,
#               'longitude': 147.0231,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 64,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:40:30',
#               'latitude': -36.934,
#               'longitude': 142.5759,
#               'surface_temperature_celcius': 47},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 59,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:39:10',
#               'latitude': -38.0383,
#               'longitude': 144.4307,
#               'surface_temperature_celcius': 40},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 69,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:39:10',
#               'latitude': -36.9354,
#               'longitude': 142.5807,
#               'surface_temperature_celcius': 45},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 68,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:39:10',
#               'latitude': -36.9405,
#               'longitude': 142.8627,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  'air_temperature_celcius': 17,
#  'date': '05-04-2021',
#  'hotspots': {'confidence': 69,
#               'date': '05-04-2021',
#               'datetime': '05-04-2021, 03:39:10',
#               'latitude': -37.6339,
#               'longitude': 143.4108,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 66,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:25:40',
#               'latitude': -37.7069,
#               'longitude': 142.1573,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 50,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:25:40',
#               'latitude': -36.0834,
#               'longitude': 146.5364,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 62,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:23:50',
#               'latitude': -36.3557,
#               'longitude': 141.3268,
#               'surface_temperature_celcius': 52},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 62,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:23:50',
#               'latitude': -37.6104,
#               'longitude': 147.8367,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 64,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:23:50',
#               'latitude': -37.9229,
#               'longitude': 143.64700000000002,
#               'surface_temperature_celcius': 63},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 62,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:23:50',
#               'latitude': -37.5052,
#               'longitude': 142.8636,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 51,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:22:20',
#               'latitude': -37.8177,
#               'longitude': 142.9168,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 65,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:21:20',
#               'latitude': -37.5842,
#               'longitude': 148.5717,
#               'surface_temperature_celcius': 49},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 64,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:21:00',
#               'latitude': -38.0089,
#               'longitude': 143.8976,
#               'surface_temperature_celcius': 45},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 58,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:21:00',
#               'latitude': -37.3072,
#               'longitude': 147.5003,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 50,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:20:50',
#               'latitude': -37.3556,
#               'longitude': 146.1085,
#               'surface_temperature_celcius': 47},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 59,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:20:40',
#               'latitude': -37.6806,
#               'longitude': 143.2676,
#               'surface_temperature_celcius': 51},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 58,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:20:40',
#               'latitude': -37.7212,
#               'longitude': 145.9754,
#               'surface_temperature_celcius': 52},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 59,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:20:40',
#               'latitude': -38.3343,
#               'longitude': 143.8644,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 64,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:20:40',
#               'latitude': -35.723,
#               'longitude': 142.063,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 50,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:20:40',
#               'latitude': -35.1383,
#               'longitude': 141.8172,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  'air_temperature_celcius': 19,
#  'date': '06-04-2021',
#  'hotspots': {'confidence': 52,
#               'date': '06-04-2021',
#               'datetime': '06-04-2021, 04:20:40',
#               'latitude': -36.4133,
#               'longitude': 141.0286,
#               'surface_temperature_celcius': 47},
#  'max_wind_speed': 15.9,
# ...
#  'relative_humidity': 53.8,
#  'station': 948702,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 24,
#  'date': '13-11-2021',
#  'hotspots': {'confidence': 64,
#               'date': '13-11-2021',
#               'datetime': '13-11-2021, 03:52:08',
#               'latitude': -37.954,
#               'longitude': 143.918,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.9,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 24,
#  'date': '13-11-2021',
#  'hotspots': {'confidence': 51,
#               'date': '13-11-2021',
#               'datetime': '13-11-2021, 01:16:38',
#               'latitude': -38.167,
#               'longitude': 143.841,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.9,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 24,
#  'date': '13-11-2021',
#  'hotspots': {'confidence': 62,
#               'date': '13-11-2021',
#               'datetime': '13-11-2021, 01:16:37',
#               'latitude': -38.16,
#               'longitude': 143.803,
#               'surface_temperature_celcius': 41},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.9,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 243,
#  'air_temperature_celcius': 28,
#  'date': '14-11-2021',
#  'hotspots': {'confidence': 64,
#               'date': '14-11-2021',
#               'datetime': '14-11-2021, 00:21:26',
#               'latitude': -38.527,
#               'longitude': 143.493,
#               'surface_temperature_celcius': 45},
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 48.3,
#  'station': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 243,
#  'air_temperature_celcius': 28,
#  'date': '14-11-2021',
#  'hotspots': {'confidence': 64,
#               'date': '14-11-2021',
#               'datetime': '14-11-2021, 00:21:07',
#               'latitude': -37.332,
#               'longitude': 143.375,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 48.3,
#  'station': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 194,
#  'air_temperature_celcius': 24,
#  'date': '23-11-2021',
#  'hotspots': {'confidence': 68,
#               'date': '23-11-2021',
#               'datetime': '23-11-2021, 00:15:12',
#               'latitude': -38.141,
#               'longitude': 143.183,
#               'surface_temperature_celcius': 46},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.8,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 194,
#  'air_temperature_celcius': 24,
#  'date': '23-11-2021',
#  'hotspots': {'confidence': 63,
#               'date': '23-11-2021',
#               'datetime': '23-11-2021, 00:14:47',
#               'latitude': -36.952,
#               'longitude': 144.972,
#               'surface_temperature_celcius': 60},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.8,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 183,
#  'air_temperature_celcius': 23,
#  'date': '28-11-2021',
#  'hotspots': {'confidence': 50,
#               'date': '28-11-2021',
#               'datetime': '28-11-2021, 00:33:14',
#               'latitude': -37.749,
#               'longitude': 148.297,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.8,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 227,
#  'air_temperature_celcius': 28,
#  'date': '29-11-2021',
#  'hotspots': {'confidence': 53,
#               'date': '29-11-2021',
#               'datetime': '29-11-2021, 13:17:24',
#               'latitude': -37.611,
#               'longitude': 149.27700000000002,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  'air_temperature_celcius': 28,
#  'date': '29-11-2021',
#  'hotspots': {'confidence': 68,
#               'date': '29-11-2021',
#               'datetime': '29-11-2021, 13:17:24',
#               'latitude': -37.605,
#               'longitude': 149.308,
#               'surface_temperature_celcius': 43},
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  'air_temperature_celcius': 28,
#  'date': '29-11-2021',
#  'hotspots': {'confidence': 52,
#               'date': '29-11-2021',
#               'datetime': '29-11-2021, 03:53:16',
#               'latitude': -34.282,
#               'longitude': 142.121,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  'air_temperature_celcius': 28,
#  'date': '29-11-2021',
#  'hotspots': {'confidence': 64,
#               'date': '29-11-2021',
#               'datetime': '29-11-2021, 03:52:10',
#               'latitude': -37.605,
#               'longitude': 149.326,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 52,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 23:25:57',
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 51,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 15:38:36',
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 64,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 15:38:36',
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 69,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 15:38:35',
#               'latitude': -37.58,
#               'longitude': 149.33100000000002,
#               'surface_temperature_celcius': 35},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 61,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 15:38:32',
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 62,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 12:22:15',
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 64,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 12:22:15',
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 69,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 04:34:57',
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 60,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 00:21:00',
#               'latitude': -37.637,
#               'longitude': 146.28799999999998,
#               'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 69,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 00:20:53',
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'hotspots': {'confidence': 64,
#               'date': '30-11-2021',
#               'datetime': '30-11-2021, 00:20:49',
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41},
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 131,
#  'air_temperature_celcius': 15,
#  'date': '08-12-2021',
#  'hotspots': {'confidence': 56,
#               'date': '08-12-2021',
#               'datetime': '08-12-2021, 13:11:43',
#               'latitude': -36.291,
#               'longitude': 146.159,
#               'surface_temperature_celcius': 40},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.1,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 141,
#  'air_temperature_celcius': 17,
#  'date': '10-12-2021',
#  'hotspots': {'confidence': 50,
#               'date': '10-12-2021',
#               'datetime': '10-12-2021, 00:57:59',
#               'latitude': -37.986999999999995,
#               'longitude': 144.005,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 141,
#  'air_temperature_celcius': 17,
#  'date': '10-12-2021',
#  'hotspots': {'confidence': 67,
#               'date': '10-12-2021',
#               'datetime': '10-12-2021, 00:56:57',
#               'latitude': -34.289,
#               'longitude': 141.71200000000002,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 156,
#  'air_temperature_celcius': 19,
#  'date': '12-12-2021',
#  'hotspots': {'confidence': 53,
#               'date': '12-12-2021',
#               'datetime': '12-12-2021, 00:45:38',
#               'latitude': -37.903,
#               'longitude': 145.25,
#               'surface_temperature_celcius': 44},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 152,
#  'air_temperature_celcius': 18,
#  'date': '15-12-2021',
#  'hotspots': {'confidence': 51,
#               'date': '15-12-2021',
#               'datetime': '15-12-2021, 13:17:17',
#               'latitude': -37.623000000000005,
#               'longitude': 149.32299999999998,
#               'surface_temperature_celcius': 38},
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 152,
#  'air_temperature_celcius': 18,
#  'date': '15-12-2021',
#  'hotspots': {'confidence': 65,
#               'date': '15-12-2021',
#               'datetime': '15-12-2021, 01:16:23',
#               'latitude': -38.038000000000004,
#               'longitude': 142.986,
#               'surface_temperature_celcius': 40},
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  'air_temperature_celcius': 18,
#  'date': '16-12-2021',
#  'hotspots': {'confidence': 69,
#               'date': '16-12-2021',
#               'datetime': '16-12-2021, 15:38:39',
#               'latitude': -37.624,
#               'longitude': 149.332,
#               'surface_temperature_celcius': 33},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  'air_temperature_celcius': 18,
#  'date': '16-12-2021',
#  'hotspots': {'confidence': 62,
#               'date': '16-12-2021',
#               'datetime': '16-12-2021, 04:35:15',
#               'latitude': -37.82,
#               'longitude': 142.32299999999998,
#               'surface_temperature_celcius': 54},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  'air_temperature_celcius': 18,
#  'date': '16-12-2021',
#  'hotspots': {'confidence': 59,
#               'date': '16-12-2021',
#               'datetime': '16-12-2021, 04:34:57',
#               'latitude': -37.644,
#               'longitude': 149.346,
#               'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  'air_temperature_celcius': 18,
#  'date': '16-12-2021',
#  'hotspots': {'confidence': 60,
#               'date': '16-12-2021',
#               'datetime': '16-12-2021, 00:21:11',
#               'latitude': -38.046,
#               'longitude': 144.201,
#               'surface_temperature_celcius': 48},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  'air_temperature_celcius': 18,
#  'date': '16-12-2021',
#  'hotspots': {'confidence': 53,
#               'date': '16-12-2021',
#               'datetime': '16-12-2021, 00:20:53',
#               'latitude': -37.63,
#               'longitude': 149.335,
#               'surface_temperature_celcius': 57},
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 141,
#  'air_temperature_celcius': 16,
#  'date': '24-12-2021',
#  'hotspots': {'confidence': 65,
#               'date': '24-12-2021',
#               'datetime': '24-12-2021, 13:12:01',
#               'latitude': -35.646,
#               'longitude': 142.282,
#               'surface_temperature_celcius': 32},
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.0,
#  'station': 948702,
#  'windspeed_knots': 12.0}
# {'GHI_w/m2': 223,
#  'air_temperature_celcius': 28,
#  'date': '27-12-2021',
#  'hotspots': {'confidence': 67,
#               'date': '27-12-2021',
#               'datetime': '27-12-2021, 00:02:15',
#               'latitude': -35.554,
#               'longitude': 143.30700000000002,
#               'surface_temperature_celcius': 53},
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %% [markdown]
# #### h) Find the average surface temperature (°C) for each day. You are required to only display average surface temperature (°C) and the date in the output.

# %%
cursor = db.embedded_climate_hotspot.aggregate([
    # set preserveNullAndEmptyArrays to make sure climate data with no hotspot also will be included after unwind
    {"$unwind": {
        "path": "$hotspots",
        "preserveNullAndEmptyArrays": True
    }},
    # find the average surface temperature
    {"$group":{"_id":"$date","average":{"$avg":"$hotspots.surface_temperature_celcius"}}},
    # project necessary details and also round the average value to 2 decimal places
    {"$project":{"rounded_average_surface_temperature":{"$round":["$average",2]},"date":"$_id","_id":0}},
    {"$sort" : {"date":1}} # not required to sort the date but just to make the output look neat
])

"""
How to interpret my output:
If there is no hotspot for a particular date, the value for the rounded_average_surface_temperature will be None. Otherwise,
the value for this column will be average surface temperature on that date. Please note that I had rounded the average value
for better visualization. I sorted them based on date for better visualization.
"""

for document in cursor: 
    document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
    pprint(document)
# Out:
# {'date': '31-12-2020', 'rounded_average_surface_temperature': None}
# {'date': '01-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '02-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '03-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '04-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '05-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '06-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '07-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '08-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '09-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '10-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '11-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '12-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '13-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '14-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '15-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '16-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '17-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '18-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '19-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '21-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '22-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '23-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '24-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '25-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '27-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '29-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '30-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '31-01-2021', 'rounded_average_surface_temperature': None}
# {'date': '01-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '02-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '03-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '04-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '05-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '06-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '07-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '08-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '09-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '10-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '11-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '12-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '13-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '14-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '15-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '16-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '17-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '18-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '19-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '21-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '22-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '23-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '24-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '25-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '27-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-02-2021', 'rounded_average_surface_temperature': None}
# {'date': '01-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '02-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '03-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '04-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '05-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '06-03-2021', 'rounded_average_surface_temperature': 60.5}
# {'date': '07-03-2021', 'rounded_average_surface_temperature': 64.0}
# {'date': '08-03-2021', 'rounded_average_surface_temperature': 51.5}
# {'date': '09-03-2021', 'rounded_average_surface_temperature': 46.67}
# {'date': '10-03-2021', 'rounded_average_surface_temperature': 69.38}
# {'date': '11-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '12-03-2021', 'rounded_average_surface_temperature': 88.2}
# {'date': '13-03-2021', 'rounded_average_surface_temperature': 38.5}
# {'date': '14-03-2021', 'rounded_average_surface_temperature': 65.6}
# {'date': '15-03-2021', 'rounded_average_surface_temperature': 46.0}
# {'date': '16-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '17-03-2021', 'rounded_average_surface_temperature': 59.5}
# {'date': '18-03-2021', 'rounded_average_surface_temperature': 79.33}
# {'date': '19-03-2021', 'rounded_average_surface_temperature': 65.57}
# {'date': '20-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '21-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '22-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '23-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '24-03-2021', 'rounded_average_surface_temperature': 49.0}
# {'date': '25-03-2021', 'rounded_average_surface_temperature': 66.0}
# {'date': '26-03-2021', 'rounded_average_surface_temperature': 56.88}
# {'date': '27-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-03-2021', 'rounded_average_surface_temperature': 60.93}
# {'date': '29-03-2021', 'rounded_average_surface_temperature': 51.0}
# {'date': '30-03-2021', 'rounded_average_surface_temperature': None}
# {'date': '31-03-2021', 'rounded_average_surface_temperature': 48.73}
# {'date': '01-04-2021', 'rounded_average_surface_temperature': 46.71}
# {'date': '02-04-2021', 'rounded_average_surface_temperature': 45.2}
# {'date': '03-04-2021', 'rounded_average_surface_temperature': 58.44}
# {'date': '04-04-2021', 'rounded_average_surface_temperature': 62.57}
# {'date': '05-04-2021', 'rounded_average_surface_temperature': 53.14}
# {'date': '06-04-2021', 'rounded_average_surface_temperature': 61.71}
# {'date': '07-04-2021', 'rounded_average_surface_temperature': 50.69}
# {'date': '08-04-2021', 'rounded_average_surface_temperature': 60.75}
# {'date': '09-04-2021', 'rounded_average_surface_temperature': None}
# {'date': '10-04-2021', 'rounded_average_surface_temperature': None}
# {'date': '11-04-2021', 'rounded_average_surface_temperature': 46.29}
# {'date': '12-04-2021', 'rounded_average_surface_temperature': 52.7}
# {'date': '13-04-2021', 'rounded_average_surface_temperature': 58.58}
# {'date': '14-04-2021', 'rounded_average_surface_temperature': 61.94}
# {'date': '15-04-2021', 'rounded_average_surface_temperature': 59.58}
# {'date': '16-04-2021', 'rounded_average_surface_temperature': 48.72}
# {'date': '17-04-2021', 'rounded_average_surface_temperature': 50.92}
# {'date': '18-04-2021', 'rounded_average_surface_temperature': 53.37}
# {'date': '19-04-2021', 'rounded_average_surface_temperature': 54.16}
# {'date': '20-04-2021', 'rounded_average_surface_temperature': 56.58}
# {'date': '21-04-2021', 'rounded_average_surface_temperature': None}
# {'date': '22-04-2021', 'rounded_average_surface_temperature': 54.5}
# {'date': '23-04-2021', 'rounded_average_surface_temperature': 53.89}
# {'date': '24-04-2021', 'rounded_average_surface_temperature': 59.38}
# {'date': '25-04-2021', 'rounded_average_surface_temperature': 48.67}
# {'date': '26-04-2021', 'rounded_average_surface_temperature': 34.0}
# {'date': '27-04-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-04-2021', 'rounded_average_surface_temperature': None}
# {'date': '29-04-2021', 'rounded_average_surface_temperature': 63.0}
# {'date': '30-04-2021', 'rounded_average_surface_temperature': None}
# {'date': '01-05-2021', 'rounded_average_surface_temperature': 68.4}
# {'date': '02-05-2021', 'rounded_average_surface_temperature': 55.6}
# {'date': '03-05-2021', 'rounded_average_surface_temperature': 56.8}
# {'date': '04-05-2021', 'rounded_average_surface_temperature': 56.81}
# {'date': '05-05-2021', 'rounded_average_surface_temperature': 51.71}
# {'date': '06-05-2021', 'rounded_average_surface_temperature': 57.53}
# {'date': '07-05-2021', 'rounded_average_surface_temperature': 50.33}
# {'date': '08-05-2021', 'rounded_average_surface_temperature': 56.29}
# {'date': '09-05-2021', 'rounded_average_surface_temperature': 42.46}
# {'date': '10-05-2021', 'rounded_average_surface_temperature': 52.87}
# {'date': '11-05-2021', 'rounded_average_surface_temperature': 59.37}
# {'date': '12-05-2021', 'rounded_average_surface_temperature': 51.5}
# {'date': '13-05-2021', 'rounded_average_surface_temperature': 58.61}
# {'date': '14-05-2021', 'rounded_average_surface_temperature': 49.0}
# {'date': '15-05-2021', 'rounded_average_surface_temperature': 53.95}
# {'date': '16-05-2021', 'rounded_average_surface_temperature': 39.67}
# {'date': '17-05-2021', 'rounded_average_surface_temperature': 52.0}
# {'date': '18-05-2021', 'rounded_average_surface_temperature': 44.14}
# {'date': '19-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '21-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '22-05-2021', 'rounded_average_surface_temperature': 54.48}
# {'date': '23-05-2021', 'rounded_average_surface_temperature': 51.2}
# {'date': '24-05-2021', 'rounded_average_surface_temperature': 40.33}
# {'date': '25-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-05-2021', 'rounded_average_surface_temperature': 49.5}
# {'date': '27-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '29-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '30-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '31-05-2021', 'rounded_average_surface_temperature': None}
# {'date': '01-06-2021', 'rounded_average_surface_temperature': 54.0}
# {'date': '02-06-2021', 'rounded_average_surface_temperature': 47.73}
# {'date': '03-06-2021', 'rounded_average_surface_temperature': 47.0}
# {'date': '04-06-2021', 'rounded_average_surface_temperature': 52.22}
# {'date': '05-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '06-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '07-06-2021', 'rounded_average_surface_temperature': 51.86}
# {'date': '08-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '09-06-2021', 'rounded_average_surface_temperature': 49.0}
# {'date': '10-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '11-06-2021', 'rounded_average_surface_temperature': 41.5}
# {'date': '12-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '13-06-2021', 'rounded_average_surface_temperature': 41.0}
# {'date': '14-06-2021', 'rounded_average_surface_temperature': 53.25}
# {'date': '15-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '16-06-2021', 'rounded_average_surface_temperature': 42.5}
# {'date': '17-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '18-06-2021', 'rounded_average_surface_temperature': 42.0}
# {'date': '19-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-06-2021', 'rounded_average_surface_temperature': 71.17}
# {'date': '21-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '22-06-2021', 'rounded_average_surface_temperature': 46.0}
# {'date': '23-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '24-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '25-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '27-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '29-06-2021', 'rounded_average_surface_temperature': None}
# {'date': '30-06-2021', 'rounded_average_surface_temperature': 44.33}
# {'date': '01-07-2021', 'rounded_average_surface_temperature': 30.5}
# {'date': '02-07-2021', 'rounded_average_surface_temperature': 43.5}
# {'date': '03-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '04-07-2021', 'rounded_average_surface_temperature': 40.0}
# {'date': '05-07-2021', 'rounded_average_surface_temperature': 45.0}
# {'date': '06-07-2021', 'rounded_average_surface_temperature': 56.0}
# {'date': '07-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '08-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '09-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '10-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '11-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '12-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '13-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '14-07-2021', 'rounded_average_surface_temperature': 41.5}
# {'date': '15-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '16-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '17-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '18-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '19-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '21-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '22-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '23-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '24-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '25-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '27-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '29-07-2021', 'rounded_average_surface_temperature': 48.0}
# {'date': '30-07-2021', 'rounded_average_surface_temperature': None}
# {'date': '31-07-2021', 'rounded_average_surface_temperature': 47.0}
# {'date': '01-08-2021', 'rounded_average_surface_temperature': 58.0}
# {'date': '02-08-2021', 'rounded_average_surface_temperature': 63.5}
# {'date': '03-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '04-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '05-08-2021', 'rounded_average_surface_temperature': 40.0}
# {'date': '06-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '07-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '08-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '09-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '10-08-2021', 'rounded_average_surface_temperature': 63.0}
# {'date': '11-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '12-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '13-08-2021', 'rounded_average_surface_temperature': 49.0}
# {'date': '14-08-2021', 'rounded_average_surface_temperature': 40.8}
# {'date': '15-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '16-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '17-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '18-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '19-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '21-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '22-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '23-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '24-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '25-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '27-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '29-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '30-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '31-08-2021', 'rounded_average_surface_temperature': None}
# {'date': '01-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '02-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '03-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '04-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '05-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '06-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '07-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '08-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '09-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '10-09-2021', 'rounded_average_surface_temperature': 56.5}
# {'date': '11-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '12-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '13-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '14-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '15-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '16-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '17-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '18-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '19-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-09-2021', 'rounded_average_surface_temperature': 63.6}
# {'date': '21-09-2021', 'rounded_average_surface_temperature': 40.5}
# {'date': '22-09-2021', 'rounded_average_surface_temperature': 45.0}
# {'date': '23-09-2021', 'rounded_average_surface_temperature': 52.74}
# {'date': '24-09-2021', 'rounded_average_surface_temperature': 53.57}
# {'date': '25-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-09-2021', 'rounded_average_surface_temperature': 33.0}
# {'date': '27-09-2021', 'rounded_average_surface_temperature': 49.71}
# {'date': '28-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '29-09-2021', 'rounded_average_surface_temperature': 43.0}
# {'date': '30-09-2021', 'rounded_average_surface_temperature': None}
# {'date': '01-10-2021', 'rounded_average_surface_temperature': 48.25}
# {'date': '02-10-2021', 'rounded_average_surface_temperature': 43.57}
# {'date': '03-10-2021', 'rounded_average_surface_temperature': 50.0}
# {'date': '04-10-2021', 'rounded_average_surface_temperature': 49.0}
# {'date': '05-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '06-10-2021', 'rounded_average_surface_temperature': 44.0}
# {'date': '07-10-2021', 'rounded_average_surface_temperature': 42.0}
# {'date': '08-10-2021', 'rounded_average_surface_temperature': 41.0}
# {'date': '09-10-2021', 'rounded_average_surface_temperature': 44.0}
# {'date': '10-10-2021', 'rounded_average_surface_temperature': 53.33}
# {'date': '11-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '12-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '13-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '14-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '15-10-2021', 'rounded_average_surface_temperature': 72.67}
# {'date': '16-10-2021', 'rounded_average_surface_temperature': 36.0}
# {'date': '17-10-2021', 'rounded_average_surface_temperature': 51.6}
# {'date': '18-10-2021', 'rounded_average_surface_temperature': 52.17}
# {'date': '19-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-10-2021', 'rounded_average_surface_temperature': 50.0}
# {'date': '21-10-2021', 'rounded_average_surface_temperature': 51.25}
# {'date': '22-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '23-10-2021', 'rounded_average_surface_temperature': 38.0}
# {'date': '24-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '25-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-10-2021', 'rounded_average_surface_temperature': 44.6}
# {'date': '27-10-2021', 'rounded_average_surface_temperature': 50.4}
# {'date': '28-10-2021', 'rounded_average_surface_temperature': 56.0}
# {'date': '29-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '30-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '31-10-2021', 'rounded_average_surface_temperature': None}
# {'date': '01-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '02-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '03-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '04-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '05-11-2021', 'rounded_average_surface_temperature': 58.5}
# {'date': '06-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '07-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '08-11-2021', 'rounded_average_surface_temperature': 45.5}
# {'date': '09-11-2021', 'rounded_average_surface_temperature': 61.3}
# {'date': '10-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '11-11-2021', 'rounded_average_surface_temperature': 46.25}
# {'date': '12-11-2021', 'rounded_average_surface_temperature': 53.0}
# {'date': '13-11-2021', 'rounded_average_surface_temperature': 47.0}
# {'date': '14-11-2021', 'rounded_average_surface_temperature': 52.0}
# {'date': '15-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '16-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '17-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '18-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '19-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '21-11-2021', 'rounded_average_surface_temperature': 59.0}
# {'date': '22-11-2021', 'rounded_average_surface_temperature': 61.5}
# {'date': '23-11-2021', 'rounded_average_surface_temperature': 58.8}
# {'date': '24-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '25-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '26-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '27-11-2021', 'rounded_average_surface_temperature': None}
# {'date': '28-11-2021', 'rounded_average_surface_temperature': 42.0}
# {'date': '29-11-2021', 'rounded_average_surface_temperature': 60.62}
# {'date': '30-11-2021', 'rounded_average_surface_temperature': 52.42}
# {'date': '01-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '02-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '03-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '04-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '05-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '06-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '07-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '08-12-2021', 'rounded_average_surface_temperature': 50.6}
# {'date': '09-12-2021', 'rounded_average_surface_temperature': 58.25}
# {'date': '10-12-2021', 'rounded_average_surface_temperature': 46.0}
# {'date': '11-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '12-12-2021', 'rounded_average_surface_temperature': 44.0}
# {'date': '13-12-2021', 'rounded_average_surface_temperature': 60.0}
# {'date': '14-12-2021', 'rounded_average_surface_temperature': 70.0}
# {'date': '15-12-2021', 'rounded_average_surface_temperature': 39.0}
# {'date': '16-12-2021', 'rounded_average_surface_temperature': 57.8}
# {'date': '17-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '18-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '19-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '20-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '21-12-2021', 'rounded_average_surface_temperature': 46.0}
# {'date': '22-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '23-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '24-12-2021', 'rounded_average_surface_temperature': 32.0}
# {'date': '25-12-2021', 'rounded_average_surface_temperature': 54.0}
# {'date': '26-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '27-12-2021', 'rounded_average_surface_temperature': 62.75}
# {'date': '28-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '29-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '30-12-2021', 'rounded_average_surface_temperature': None}
# {'date': '31-12-2021', 'rounded_average_surface_temperature': None}

# %% [markdown]
# #### i) Find the top 10 records with the lowest GHI.

# %%
cursor = db.embedded_climate_hotspot.aggregate([
    {"$project":{"_id":0,"hotspots":0}},
    {"$sort" : {"GHI_w/m2":1}},
    {"$limit" : 10 }    # only the top 10 records with the lowest GHI
])

"""
How to interpret my output:
Similar to question e, my output shows all the details (i.e., climate data) for the top 10 records with the lowest GHI. 
The reason for this is because this is more convenient as it allows the client/user to retrieve all 
the details for these records. Besides that, since the question did not explicitly ask us to show the 
hotspots and to simplify the output, I did not show the hotspots. Otherwise, the output would be too long and complex.
If the marker want to see the hotspots data, please remove the "hotspots":0 above, thank you.
"""

for document in cursor: 
    document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
    pprint(document)
# Out:
# {'GHI_w/m2': 47,
#  'air_temperature_celcius': 5,
#  'date': '02-08-2021',
#  'max_wind_speed': 5.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 48,
#  'air_temperature_celcius': 5,
#  'date': '30-06-2021',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 49,
#  'air_temperature_celcius': 5,
#  'date': '01-07-2021',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 56,
#  'air_temperature_celcius': 6,
#  'date': '11-07-2021',
#  'max_wind_speed': 5.1,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 57,
#  'air_temperature_celcius': 6,
#  'date': '15-07-2021',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 60,
#  'air_temperature_celcius': 6,
#  'date': '02-07-2021',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 65,
#  'air_temperature_celcius': 7,
#  'date': '01-08-2021',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 65,
#  'air_temperature_celcius': 7,
#  'date': '20-07-2021',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 65,
#  'air_temperature_celcius': 7,
#  'date': '31-07-2021',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'GHI_w/m2': 66,
#  'air_temperature_celcius': 7,
#  'date': '19-08-2021',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %% [markdown]
# #### j) Find the records with a 24-hour precipitation recorded between 0.20 to 0.35.

# %%
cursor = db.embedded_climate_hotspot.aggregate([
    # find the records such that the precipitation column end with either G, D or F
    {"$match":{"precipitation ": {"$regex": "(G|D|F)$"}}}, 
    {"$project":{"_id":0,"hotspots":0}}
])

"""
How to interpret my output:
Since the question did not explicitly ask us to show the hotspots and to simplify the output, I did not show the hotspots. 
Hence, I only shows the climate data for the records with a 24-hour precipitation recorded between 0.20 to 0.35.
If the marker want to see the hotspots data, please remove the "hotspots":0 above, thank you.
"""

for document in cursor: 
    document['date'] = document['date'].strftime('%d-%m-%Y') # make the date more readable
    current = document['precipitation ']
    current = float(current[1:5])                            # get the amount of precipitation
    if current >= 0.20 and current <= 0.35:
        pprint(document)
# Out:
# {'GHI_w/m2': 157,
#  'air_temperature_celcius': 19,
#  'date': '13-01-2021',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  'air_temperature_celcius': 17,
#  'date': '29-03-2021',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  'air_temperature_celcius': 20,
#  'date': '20-04-2021',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  'air_temperature_celcius': 11,
#  'date': '26-04-2021',
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  'air_temperature_celcius': 14,
#  'date': '27-05-2021',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.35G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  'air_temperature_celcius': 8,
#  'date': '30-05-2021',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  'air_temperature_celcius': 11,
#  'date': '03-07-2021',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  'air_temperature_celcius': 11,
#  'date': '27-07-2021',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  'air_temperature_celcius': 9,
#  'date': '06-08-2021',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  'air_temperature_celcius': 11,
#  'date': '26-08-2021',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  'air_temperature_celcius': 8,
#  'date': '05-09-2021',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  'air_temperature_celcius': 10,
#  'date': '07-09-2021',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  'air_temperature_celcius': 11,
#  'date': '15-09-2021',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  'air_temperature_celcius': 12,
#  'date': '05-10-2021',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  'air_temperature_celcius': 17,
#  'date': '29-10-2021',
#  'max_wind_speed': 27.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  'air_temperature_celcius': 11,
#  'date': '30-10-2021',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  'air_temperature_celcius': 18,
#  'date': '16-11-2021',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  'air_temperature_celcius': 19,
#  'date': '17-11-2021',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  'air_temperature_celcius': 26,
#  'date': '30-11-2021',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
